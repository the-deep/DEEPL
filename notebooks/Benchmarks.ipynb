# %%
# !pip3 install pandas numpy --user
# Out:
# Collecting pandas
#   Using cached https://files.pythonhosted.org/packages/67/a7/12261a51ac2e7be4c698ca27cbe364ca5f16d64999456ee47ea8c7b44417/pandas-0.23.4-cp37-cp37m-manylinux1_x86_64.whl
# Collecting numpy
#   Using cached https://files.pythonhosted.org/packages/98/44/94cc2e139b611b16458384ff3b9c87f217144b5915b0a9798c07a7295437/numpy-1.15.2-cp37-cp37m-manylinux1_x86_64.whl
# Collecting pytz>=2011k (from pandas)
#   Using cached https://files.pythonhosted.org/packages/30/4e/27c34b62430286c6d59177a0842ed90dc789ce5d1ed740887653b898779a/pytz-2018.5-py2.py3-none-any.whl
# Requirement already satisfied: python-dateutil>=2.5.0 in /home/deepl/.local/lib/python3.7/site-packages (from pandas) (2.7.3)
# Requirement already satisfied: six>=1.5 in /home/deepl/.local/lib/python3.7/site-packages (from python-dateutil>=2.5.0->pandas) (1.11.0)
# Installing collected packages: numpy, pytz, pandas
# Successfully installed numpy-1.15.2 pandas-0.23.4 pytz-2018.5

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../../data/processed_new_data.csv", header=0)

# %% [markdown]
# ## Text Preprocessing
#
# Before the text is fed into the classifier, the following steps are taken:
#
# 1. Detect language
# 2. Translate into English
# 3. Lemmatization
# 4. Remove punctuation but not numbers
# 5. Stop word removal
# 6. Join strings separated by a space
# 7. Converts the string into lower case characters
# 8. Converts everything into a string

# %%
# !pip3 install nltk --user
# Out:
# Collecting nltk
#   Using cached https://files.pythonhosted.org/packages/50/09/3b1755d528ad9156ee7243d52aa5cd2b809ef053a0f31b53d92853dd653a/nltk-3.3.0.zip
# Requirement already satisfied: six in /home/deepl/.local/lib/python3.7/site-packages (from nltk) (1.11.0)
# Installing collected packages: nltk
#   Running setup.py install for nltk ... done
# Successfully installed nltk-3.3

# %%
# !pip3 install googletrans langid --user
# Out:
# Collecting googletrans
#   Using cached https://files.pythonhosted.org/packages/49/0f/eac53560e99a6b1e3b3e18e8b98f0e0041bfc4f1ee1e1b74cdf5530786d0/googletrans-2.3.0.tar.gz
# Collecting langid
#   Using cached https://files.pythonhosted.org/packages/ea/4c/0fb7d900d3b0b9c8703be316fbddffecdab23c64e1b46c7a83561d78bd43/langid-1.1.6.tar.gz
# Collecting requests (from googletrans)
#   Using cached https://files.pythonhosted.org/packages/65/47/7e02164a2a3db50ed6d8a6ab1d6d60b69c4c3fdf57a284257925dfc12bda/requests-2.19.1-py2.py3-none-any.whl
# Requirement already satisfied: numpy in /home/deepl/.local/lib/python3.7/site-packages (from langid) (1.15.2)
# Collecting certifi>=2017.4.17 (from requests->googletrans)
#   Using cached https://files.pythonhosted.org/packages/df/f7/04fee6ac349e915b82171f8e23cee63644d83663b34c539f7a09aed18f9e/certifi-2018.8.24-py2.py3-none-any.whl
# Collecting urllib3<1.24,>=1.21.1 (from requests->googletrans)
#   Using cached https://files.pythonhosted.org/packages/bd/c9/6fdd990019071a4a32a5e7cb78a1d92c53851ef4f56f62a3486e6a7d8ffb/urllib3-1.23-py2.py3-none-any.whl
# Collecting idna<2.8,>=2.5 (from requests->googletrans)
#   Using cached https://files.pythonhosted.org/packages/4b/2a/0276479a4b3caeb8a8c1af2f8e4355746a97fab05a372e4a2c6a6b876165/idna-2.7-py2.py3-none-any.whl
# Collecting chardet<3.1.0,>=3.0.2 (from requests->googletrans)
#   Using cached https://files.pythonhosted.org/packages/bc/a9/01ffebfb562e4274b6487b4bb1ddec7ca55ec7510b22e4c51f14098443b8/chardet-3.0.4-py2.py3-none-any.whl
# Installing collected packages: certifi, urllib3, idna, chardet, requests, googletrans, langid
#   Running setup.py install for googletrans ... done
#   Running setup.py install for langid ... done
# Successfully installed certifi-2018.8.24 chardet-3.0.4 googletrans-2.3.0 idna-2.7 langid-1.1.6 requests-2.19.1 urllib3-1.23

# %%
import nltk

from nltk.stem.wordnet import WordNetLemmatizer
import string
import re
from nltk.corpus import wordnet as wn
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package wordnet to /home/deepl/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/deepl/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
nltk_wordnet_tag_map = {
    'NN': wn.NOUN,
    'NNS': wn.NOUN,
    'VBP': wn.VERB,
    'VBG': wn.VERB,
    'JJ': wn.ADJ,
}

from functools import reduce

def compose(*functions):
    def compose2(f1, f2):
        """Compose two functions"""
        return lambda *args: f1(f2(*args))
    return reduce(compose2, functions)

def translate_to_english_txt(row):
    text = row["excerpt"]
    try:
        if langid.classify(text)[0] != 'en':
            trans = googletrans.client.Translator()
            return trans.translate(text, 'en').text
        return text
    except Exception as e:
        return ''
    
def lemmatize(row, lemmatizer=WordNetLemmatizer()):
    text = row
    splitted = text if type(text) == list else str(text).split()
    splitted = list(map(lambda x: str(x).lower(), splitted))
    tagged = nltk.pos_tag(splitted)
    lemmatized = []
    for word, tag in tagged:
        wnet_tag = nltk_wordnet_tag_map.get(tag)
        if wnet_tag:
            lemmatized.append(lemmatizer.lemmatize(word, wnet_tag))
        else:
            lemmatized.append(word)
    return ' '.join(lemmatized)

def rm_punc_not_nums(inp, col=None):
    """Remove punctuation unless it's a number for either a df (and col)
    or single entry
    """
    punc = string.punctuation
    transtable = str.maketrans("", "", punc)

    def sing_rm(phr):
        """Remove for a single entity"""
        return ' '.join([re.sub('\W+', '', i).translate(transtable) if not (
                    all(j.isdigit() or j in punc for j in i)
                    and
                    any(j.isdigit() for j in i)
                ) else re.sub('\W+', '', i)
                for i in str(phr).split(' ')]
        )
    if col and isinstance(inp, pd.core.frame.DataFrame):
        return inp.filter(like=col).applymap(lambda phr: sing_rm(phr))
    elif isinstance(inp, str):
        return sing_rm(inp)
    else:
        raise Exception('Not a vaild type')


def rm_stop_words_txt(txt, swords=nltk.corpus.stopwords.words('english')):
    """ Remove stop words from given text """
    return ' '.join(
        [token for token in str(txt).split(' ')
            if token.lower() not in swords]
    )

# %% [markdown]
# ## Sanity Check

# %%
data = {"excerpt": "The 2 quick brown foxes jumped over the lazy dogs!"}

def preprocess(row):
        inp = row["excerpt"]
        inp = lemmatize(inp)
        func = compose(
            rm_punc_not_nums,
            rm_stop_words_txt,
            ' '.join,
            str.split,
            str.lower,
            str
        )
        
        return func(inp)

preprocess(data)
# Out:
# '2 quick brown fox jumped lazy dogs'

# %%
df = pd.read_csv("../../data/all_en_processed_sectors_subsectors.csv")

# %%
df.drop(["Unnamed: 0", "Unnamed: 0.1"], axis=1, inplace=True)

# %%
df["preprocessed_excerpt"] = df.apply(preprocess, axis=1)

# %%
df
# Out:
#             sector                                          subsector  \
# 0        Nutrition                                      Breastfeeding
# 1           Health                             Health status and risk
# 2             Food                                                NaN
# 3           Health                                                NaN
# 4            Cross                                                NaN
# 5            Cross                                                NaN
# 6             Food                                                NaN
# 7          Shelter                Shelter infrastructure and material
# 8       Protection  Sexual violence and other forms of Gender Base...
# 9       Protection  Sexual violence and other forms of Gender Base...
# 10           Cross                                                NaN
# 11            Food                                                NaN
# 12            Food                                                NaN
# 13            Food                                                NaN
# 14            Food                                                NaN
# 15          Health                                                NaN
# 16       Nutrition                                     Undernutrition
# 17          Health                             Health status and risk
# 18       Nutrition                                                NaN
# 19          Health                                                NaN
# 20       Education                                                NaN
# 21          Health                                                NaN
# 22      Livelihood                                                NaN
# 23          Health                          Health system performance
# 24             NFI                                                NaN
# 25            WASH                                                NaN
# 26      Protection                                                NaN
# 27      Protection                                                NaN
# 28      Protection                                                NaN
# 29            Food                                                NaN
# ...            ...                                                ...
# 16436        Cross                                                NaN
# 16437         Food                                                NaN
# 16438  Agriculture                                                NaN
# 16439  Agriculture                                                NaN
# 16440    Education                                                NaN
# 16441      Shelter                                                NaN
# 16442      Shelter                                                NaN
# 16443       Health                                                NaN
# 16444      Shelter                                                NaN
# 16445    Education                                                NaN
# 16446  Agriculture                                                NaN
# 16447    Nutrition                                                NaN
# 16448    Nutrition                                                NaN
# 16449   Protection                                                NaN
# 16450   Protection                                                NaN
# 16451      Shelter                                                NaN
# 16452         Food                                                NaN
# 16453       Health                                                NaN
# 16454       Health                                                NaN
# 16455         Food                                                NaN
# 16456         WASH                                                NaN
# 16457   Protection                                                NaN
# 16458         Food                                                NaN
# 16459         Food                                                NaN
# 16460         Food                                                NaN
# 16461         Food                                                NaN
# 16462    Education                                                NaN
# 16463    Education                                                NaN
# 16464    Education                                                NaN
# 16465   Protection                                                NaN
#
#                                                  excerpt  \
# 0      112,500 children under five are at risk of acu...
# 1      2,271 cholera cases suspected between 4-19 Oct...
# 2           806,000 people need urgent food assistance.
# 3                       36 health facilities destroyed.
# 4                            1.4 million People need aid
# 5      Humanitarian needs are said to include access ...
# 6      The people in urgent food insecurity are locat...
# 7      Following the government’s announcement to clo...
# 8      Exacerbating the pre-existing displacement cri...
# 9      Agencies have expressed serious concerns about...
# 10     The Humanitarian Country Team (HCT) in Haiti, ...
# 11     In-kind contributions have also been made to e...
# 12      More than 806,000 people are at extreme food ...
# 13     In addition to $775,000 from the disbursed eme...
# 14     From 8 to 20 October, WFP reached 173,100 peop...
# 15     An estimated 900,000 people are expected to ne...
# 16     Nearly 112,500 children under age five are at ...
# 17     Around 2,271 suspected cases of cholera report...
# 18     There are concerns that unsolicited donations ...
# 19     Restoring basic health and nutrition services ...
# 20     An estimated 116,000 children are out of schoo...
# 21     An estimated 36,900 people in Grand’Anse and S...
# 22     ON- Five hospitals and one mobile clinic were ...
# 23     A second hospital in western Aleppo was hit by...
# 24     A third hospital in western Aleppo was hit by ...
# 25     One of the damaged facilities in Western Rural...
# 26     The two hospitals in Idleb were providing almo...
# 27     Since July, 275,000 civilians have been trappe...
# 28     Gender inequality is both the cause and the co...
# 29     A third of women will experience violence at s...
# ...                                                  ...
# 16436  Cross River records 15 deaths in 2 months Floo...
# 16437  According to a recent WFP analysis, food consu...
# 16438  In addition, the Government of Cameroon Minist...
# 16439  The holder of Carbap, Matías De Velazco, said ...
# 16440  For residents, however, the presence of the ar...
# 16441  The government of Tanzania said on Tuesday it ...
# 16442  More than 100 Maasai huts in Tanzania have bee...
# 16443  Dr. Abdul’Aziz Manga, the Executive Chairman o...
# 16444  The most vulnerable areas are still Regent and...
# 16445  Government officials and partners are also act...
# 16446  Predicted increase of precipitations from this...
# 16447  Close to 800,000 children under the age of fiv...
# 16448  Close to 800,000 children under the age of fiv...
# 16449  Hawija has 100,000 besieged civilians. The mil...
# 16450                                                NaN
# 16451  13 cholera dead in South Darfur capitalTwo peo...
# 16452  \r\nFood Security Outlook \r\n\r\nThe overall ...
# 16453  Yemen’s cholera outbreak has infected 612,703 ...
# 16454                                                NaN
# 16455  Nana-Gribizi Prefecture / Kaga-Bandoro / Kaga-...
# 16456  Prefecture of Ouham / Batangafo Sub-prefecture...
# 16457  Myanmar has been laying landmines across a sec...
# 16458  Food prices are rising in the city of Bouca an...
# 16459  The surge in food prices in and around Bouca i...
# 16460  Bouca since a few months is the hub between th...
# 16461  food availability and accessibility improved b...
# 16462  Of the ten regions in the country, two have pa...
# 16463  A few students were sighted on Monday Septembe...
# 16464  The situation is calm since Tuesday, September...
# 16465  In Zemio, more than 1,000 kilometers from Bang...
#
#                                     preprocessed_excerpt
# 0              112500 child five risk acute malnutrition
# 1          2271 cholera case suspected 419 october alone
# 2              806000 people need urgent food assistance
# 3                           36 health facility destroyed
# 4                             14 million people need aid
# 5      humanitarian need said include access sufficie...
# 6      people urgent food insecurity located area 75 ...
# 7      follow governments announcement close temporar...
# 8      exacerbate preexisting displacement crisis ten...
# 9      agency expressed serious concern risk increase...
# 10     humanitarian country team hct haiti coordinati...
# 11     inkind contribution also made extend support g...
# 12     806000 people extreme food insecurity affected...
# 13     addition 775000 disbursed emergency fund trans...
# 14     8 20 october wfp reached 173100 people 1150mt ...
# 15     estimated 900000 people expected need vaccinat...
# 16     nearly 112500 child age five risk acute malnut...
# 17     around 2271 suspected case cholera reported 41...
# 18     concern unsolicited donation breastmilk substi...
# 19     restore basic health nutrition service particu...
# 20     estimated 116000 child school number likely ri...
# 21     estimated 36900 people grandanse sud targeted ...
# 22     on five hospital one mobile clinic attacked sy...
# 23     second hospital western aleppo hit airstrike 2...
# 24     third hospital western aleppo hit airstrike 11...
# 25     one damaged facility western rural aleppo fron...
# 26     two hospital idleb provide almost 10 000 consu...
# 27     since july 275000 civilian trapped eastern ale...
# 28     gender inequality cause consequence violence w...
# 29     third woman experience violence point life vio...
# ...                                                  ...
# 16436  cross river record 15 death 2 month floodfifte...
# 16437  accord recent wfp analysis food consumption le...
# 16438  addition government cameroon ministry agricult...
# 16439  holder carbap matías de velazco said flood pro...
# 16440  residents however presence armed force police ...
# 16441  government tanzania said tuesday soon start de...
# 16442  100 maasai hut tanzania allegedly burned game ...
# 16443  dr abdulaziz manga executive chairman bauchi s...
# 16444  vulnerable area still regent kamayama directly...
# 16445  government official partner also actively prep...
# 16446  predicted increase precipitation month septemb...
# 16447  close 800000 child age five suffer severe acut...
# 16448  close 800000 child age five suffer severe acut...
# 16449  hawija 100000 besieged civilians militant grou...
# 16450                                                nan
# 16451  13 cholera dead south darfur capitaltwo people...
# 16452  food security outlook overall high food price ...
# 16453  yemens cholera outbreak infected 612703 people...
# 16454                                                nan
# 16455  nanagribizi prefecture  kagabandoro  kagabando...
# 16456  prefecture ouham  batangafo subprefecture  bat...
# 16457  myanmar lay landmines across section border ba...
# 16458  food price rise city bouca surround areas acco...
# 16459  surge food price around bouca confirmed severa...
# 16460  bouca since month hub town batangafo guise arm...
# 16461  food availability accessibility improved june ...
# 16462  ten region country two particularly polarized ...
# 16463  student sighted monday september 4th way schoo...
# 16464  situation calm since tuesday september 5 morni...
# 16465  zemio 1000 kilometer bangui extreme southeast ...
#
# [16466 rows x 4 columns]

# %%
merged_df = pd.DataFrame(df.groupby('preprocessed_excerpt')["sector"].apply(set)).reset_index()

# %%
# !pip3 install sklearn --user
# Out:
# Collecting sklearn
#   Using cached https://files.pythonhosted.org/packages/1e/7a/dbb3be0ce9bd5c8b7e3d87328e79063f8b263b2b1bfa4774cb1147bfcd3f/sklearn-0.0.tar.gz
# Collecting scikit-learn (from sklearn)
#   Using cached https://files.pythonhosted.org/packages/56/7d/0737aed3e157fb90a1eaecb1cbfa5742fa4206fb305c8f157b666b71da14/scikit_learn-0.20.0-cp37-cp37m-manylinux1_x86_64.whl
# Collecting scipy>=0.13.3 (from scikit-learn->sklearn)
#   Using cached https://files.pythonhosted.org/packages/40/de/0c22c6754370ba6b1fa8e53bd6e514d4a41a181125d405a501c215cbdbd6/scipy-1.1.0-cp37-cp37m-manylinux1_x86_64.whl
# Requirement already satisfied: numpy>=1.8.2 in /home/deepl/.local/lib/python3.7/site-packages (from scikit-learn->sklearn) (1.15.2)
# Installing collected packages: scipy, scikit-learn, sklearn
#   Running setup.py install for sklearn ... done
# Successfully installed scikit-learn-0.20.0 scipy-1.1.0 sklearn-0.0

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline

# %%
text_clf = Pipeline([
            ('vect', CountVectorizer(ngram_range=(1, 2))),
            ('tfidf', TfidfTransformer(use_idf=False)),
            ('clf', MultinomialNB(alpha=0.01, fit_prior=False))
        ])

# %%
temp_list = [list(x) for x in list(merged_df["sector"])]

# %%
category_columns = [j for sub in temp_list for j in sub]
category_columns = list(set(category_columns))

# %%
category_df = pd.concat([merged_df,pd.DataFrame(columns=category_columns)])
# Out:
# /home/deepl/.local/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
category_df.fillna(value=0, inplace=True)

# %%
! git config --global user.email "aayush.chadha@student.manchester.ac.uk"
! git config --global user.name "achadha0111"
! git add Benchmarks.ipynb
! git commit -m "Add benchmark notebook"
! git push --set-upstream origin benchmarks
