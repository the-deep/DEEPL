# %%
import csv
import random

import nltk
import pandas as pd
import numpy as np
import scipy.stats

# %%
#data prep

#read in csv, make dict with cats
#structure: 0 country | 1 date | 2 sect | 3 subsect | 4 text

rd = csv.reader(open('/Users/ewanog/Dropbox (Old)/DEEP dropbox/Assessment reports/GEO Data/2017-04-02-country-content-60-weeks.csv'))

cats = {}

for row in rd:
    sect = row[2]
    txt = row[4]
    if sect not in cats:
        cats[sect] = [txt]
    else:
        cats[sect].append(txt)
        
#counts
c=0
for k,v in cats.items():
    print(k + ' ' + str(len(v)))
    c+=len(v)
print('total count: ' + str(c))
    
print('all: ' + str(len(cats.values())))
    
#TODO: clean bad chars

#remove stopwords. STOP!!!!!!!!!ADSAAA!!W

#lower - then remove all the other calls
# Out:
# Education 2665
# WASH 4383
# Protection 8820
# Politics and security 7152
# Humanitarian access 4854
# Displacement 7384
# Shelter and NFIs 2886
# Health 6255
# Food security and livelihoods 9036
# Nutrition 2358
# total count: 55793
# all: 10

# %%
cats['Education'][1:100]
# Out:
# ['150,000 education staff have stopped work due to\xa0conflict, negatively impacting the entire education system in Syria. \xa0\n',
#  '1.75 million children are\xa0out of school, mainly due to the violence, insecurity, and children taking up work.\xa0\n\nOver 6,000 schools -\xa0one out of every three schools -\xa0has been damaged, destroyed, occupied by militants, or used as shelter. \xa0\xa0Only 50% of schools are functional; Ar-Raqqa, Aleppo, and\xa0Deir-ez-Zor governorates have\xa0the lowest percentage\xa0of functional schools.\n\nCritical shortages of learning materials and safe learning spaces are reported in besieged and hard-to-reach areas. In host communities, classes are overcrowded.\n\nSchools in besieged and hard-to-reach areas have been operating underground.\xa0However, the reported use of "bunker busting" missiles has discouraged many children from attending underground schools.\xa0Between 18 and 28 November 2016, six schools were hit by airstrikes in Idlib governorate.\n\nAround 24,500 children currently displaced in eastern Aleppo City are in need of education support. They\xa0have been out of school for more than two years.\xa0Many schools in the area remain inaccessible due to presence of ERW.\xa0\n',
#  'Due to the conflict, 6.1 million people are in need of education assistance, including 5.8\xa0million children.\xa01.75 million children are out of school, and 1.35 million are at risk of dropping out. \xa0\xa0\xa0The lack of education is a source of mental distress for many children, who fear for their future.\xa0\n\nIn 2016, 255 children were killed in or near schools in Syria.\xa0\n\nAround one-third of schools nationwide are inaccessible due to conflict-induced damage.\xa0At least 87 attacks were recorded on schools in 2016: Aleppo, Rural Damascus, and al Hasakeh governorates are most affected. All sides\xa0are accused of having\xa0hit schools. \xa0\xa0\xa0\n',
#  '150,000 education staff have stopped work due to\xa0conflict, negatively impacting the entire education system in Syria. \xa0\n',
#  '1.75 million children are\xa0out of school, mainly due to the violence, insecurity, and children taking up work.\xa0\n\nOver 6,000 schools -\xa0one out of every three schools -\xa0has been damaged, destroyed, occupied by militants, or used as shelter. \xa0\xa0Only 50% of schools are functional; Ar-Raqqa, Aleppo, and\xa0Deir-ez-Zor governorates have\xa0the lowest percentage\xa0of functional schools.\n\nCritical shortages of learning materials and safe learning spaces are reported in besieged and hard-to-reach areas. In host communities, classes are overcrowded.\n\nSchools in besieged and hard-to-reach areas have been operating underground.\xa0However, the reported use of "bunker busting" missiles has discouraged many children from attending underground schools.\xa0Between 18 and 28 November 2016, six schools were hit by airstrikes in Idlib governorate.\n\nAround 24,500 children currently displaced in eastern Aleppo City are in need of education support. They\xa0have been out of school for more than two years.\xa0Many schools in the area remain inaccessible due to presence of ERW.\xa0\n',
#  'Due to the conflict, 6.1 million people are in need of education assistance, including 5.8\xa0million children.\xa01.75 million children are out of school, and 1.35 million are at risk of dropping out. \xa0\xa0\xa0The lack of education is a source of mental distress for many children, who fear for their future.\xa0\n\nIn 2016, 255 children were killed in or near schools in Syria.\xa0\n\nAround one-third of schools nationwide are inaccessible due to conflict-induced damage.\xa0At least 87 attacks were recorded on schools in 2016: Aleppo, Rural Damascus, and al Hasakeh governorates are most affected. All sides\xa0are accused of having\xa0hit schools. \xa0\xa0\xa0\n',
#  '150,000 education staff have stopped work due to\xa0conflict, negatively impacting the entire education system in Syria. \xa0\n',
#  '1.75 million children are\xa0out of school, mainly due to the violence, insecurity, and children taking up work.\xa0\n\nOver 6,000 schools -\xa0one out of every three schools -\xa0has been damaged, destroyed, occupied by militants, or used as shelter. \xa0\xa0Only 50% of schools are functional; Ar-Raqqa, Aleppo, and\xa0Deir-ez-Zor governorates have\xa0the lowest percentage\xa0of functional schools.\n\nCritical shortages of learning materials and safe learning spaces are reported in besieged and hard-to-reach areas. In host communities, classes are overcrowded.\n\nSchools in besieged and hard-to-reach areas have been operating underground.\xa0However, the reported use of "bunker busting" missiles has discouraged many children from attending underground schools.\xa0Between 18 and 28 November 2016, six schools were hit by airstrikes in Idlib governorate.\n\nAround 24,500 children currently displaced in eastern Aleppo City are in need of education support. They\xa0have been out of school for more than two years.\xa0Many schools in the area remain inaccessible due to presence of ERW.\xa0\n',
#  'Due to the conflict, 6.1 million people are in need of education assistance, including 5.8\xa0million children.\xa01.75 million children are out of school, and 1.35 million are at risk of dropping out. \xa0\xa0\xa0The lack of education is a source of mental distress for many children, who fear for their future.\xa0\n\nIn 2016, 255 children were killed in or near schools in Syria.\xa0\n\nAround one-third of schools nationwide are inaccessible due to conflict-induced damage.\xa0At least 87 attacks were recorded on schools in 2016: Aleppo, Rural Damascus, and al Hasakeh governorates are most affected. All sides\xa0are accused of having\xa0hit schools. \xa0\xa0\xa0\n',
#  '150,000 education staff have stopped work due to\xa0conflict, negatively impacting the entire education system in Syria. \xa0\n',
#  '1.75 million children are\xa0out of school, mainly due to the violence, insecurity, and children taking up work.\xa0\n\nOver 6,000 schools -\xa0one out of every three schools -\xa0has been damaged, destroyed, occupied by militants, or used as shelter. \xa0\xa0Only 50% of schools are functional; Ar-Raqqa, Aleppo, and\xa0Deir-ez-Zor governorates have\xa0the lowest percentage\xa0of functional schools.\n\nCritical shortages of learning materials and safe learning spaces are reported in besieged and hard-to-reach areas. In host communities, classes are overcrowded.\n\nSchools in besieged and hard-to-reach areas have been operating underground.\xa0However, the reported use of "bunker busting" missiles has discouraged many children from attending underground schools.\xa0Between 18 and 28 November 2016, six schools were hit by airstrikes in Idlib governorate.\n\nAround 24,500 children currently displaced in eastern Aleppo City are in need of education support. They\xa0have been out of school for more than two years.\xa0Many schools in the area remain inaccessible due to presence of ERW.\xa0\n',
#  'Due to the conflict, 6.1 million people are in need of education assistance, including 5.8\xa0million children.\xa01.75 million children are out of school, and 1.35 million are at risk of dropping out. \xa0\xa0\xa0The lack of education is a source of mental distress for many children, who fear for their future.\xa0\n\nIn 2016, 255 children were killed in or near schools in Syria.\xa0\n\nAround one-third of schools nationwide are inaccessible due to conflict-induced damage.\xa0At least 87 attacks were recorded on schools in 2016: Aleppo, Rural Damascus, and al Hasakeh governorates are most affected. All sides\xa0are accused of having\xa0hit schools. \xa0\xa0\xa0\n',
#  '150,000 education staff have stopped work due to\xa0conflict, negatively impacting the entire education system in Syria. \xa0\n',
#  '1.75 million children are\xa0out of school, mainly due to the violence, insecurity, and children taking up work.\xa0\n\nOver 6,000 schools -\xa0one out of every three schools -\xa0has been damaged, destroyed, occupied by militants, or used as shelter. \xa0\xa0Only 50% of schools are functional; Ar-Raqqa, Aleppo, and\xa0Deir-ez-Zor governorates have\xa0the lowest percentage\xa0of functional schools.\n\nCritical shortages of learning materials and safe learning spaces are reported in besieged and hard-to-reach areas. In host communities, classes are overcrowded.\n\nSchools in besieged and hard-to-reach areas have been operating underground.\xa0However, the reported use of "bunker busting" missiles has discouraged many children from attending underground schools.\xa0Between 18 and 28 November 2016, six schools were hit by airstrikes in Idlib governorate.\n\nAround 24,500 children currently displaced in eastern Aleppo City are in need of education support. They\xa0have been out of school for more than two years.\xa0Many schools in the area remain inaccessible due to presence of ERW.\xa0\n',
#  'Due to the conflict, 6.1 million people are in need of education assistance, including 5.8\xa0million children.\xa01.75 million children are out of school, and 1.35 million are at risk of dropping out. \xa0\xa0\xa0The lack of education is a source of mental distress for many children, who fear for their future.\xa0\n\nIn 2016, 255 children were killed in or near schools in Syria.\xa0\n\nAround one-third of schools nationwide are inaccessible due to conflict-induced damage.\xa0At least 87 attacks were recorded on schools in 2016: Aleppo, Rural Damascus, and al Hasakeh governorates are most affected. All sides\xa0are accused of having\xa0hit schools. \xa0\xa0\xa0\n',
#  '150,000 education staff have stopped work due to\xa0conflict, negatively impacting the entire education system in Syria. \xa0\n',
#  '1.75 million children are\xa0out of school, mainly due to the violence, insecurity, and children taking up work.\xa0\n\nOver 6,000 schools -\xa0one out of every three schools -\xa0has been damaged, destroyed, occupied by militants, or used as shelter. \xa0\xa0Only 50% of schools are functional; Ar-Raqqa, Aleppo, and\xa0Deir-ez-Zor governorates have\xa0the lowest percentage\xa0of functional schools.\n\nCritical shortages of learning materials and safe learning spaces are reported in besieged and hard-to-reach areas. In host communities, classes are overcrowded.\n\nSchools in besieged and hard-to-reach areas have been operating underground.\xa0However, the reported use of "bunker busting" missiles has discouraged many children from attending underground schools.\xa0Between 18 and 28 November 2016, six schools were hit by airstrikes in Idlib governorate.\n\nAround 24,500 children currently displaced in eastern Aleppo City are in need of education support. They\xa0have been out of school for more than two years.\xa0Many schools in the area remain inaccessible due to presence of ERW.\xa0\n',
#  'Due to the conflict, 6.1 million people are in need of education assistance, including 5.8\xa0million children.\xa01.75 million children are out of school, and 1.35 million are at risk of dropping out. \xa0\xa0\xa0The lack of education is a source of mental distress for many children, who fear for their future.\xa0\n\nIn 2016, 255 children were killed in or near schools in Syria.\xa0\n\nAround one-third of schools nationwide are inaccessible due to conflict-induced damage.\xa0At least 87 attacks were recorded on schools in 2016: Aleppo, Rural Damascus, and al Hasakeh governorates are most affected. All sides\xa0are accused of having\xa0hit schools. \xa0\xa0\xa0\n',
#  '150,000 education staff have stopped work due to\xa0conflict, negatively impacting the entire education system in Syria. \xa0\n',
#  '1.75 million children are\xa0out of school, mainly due to the violence, insecurity, and children taking up work.\xa0\n\nOver 6,000 schools -\xa0one out of every three schools -\xa0has been damaged, destroyed, occupied by militants, or used as shelter. \xa0\xa0Only 50% of schools are functional; Ar-Raqqa, Aleppo, and\xa0Deir-ez-Zor governorates have\xa0the lowest percentage\xa0of functional schools.\n\nCritical shortages of learning materials and safe learning spaces are reported in besieged and hard-to-reach areas. In host communities, classes are overcrowded.\n\nSchools in besieged and hard-to-reach areas have been operating underground.\xa0However, the reported use of "bunker busting" missiles has discouraged many children from attending underground schools.\xa0Between 18 and 28 November 2016, six schools were hit by airstrikes in Idlib governorate.\n\nAround 24,500 children currently displaced in eastern Aleppo City are in need of education support. They\xa0have been out of school for more than two years.\xa0Many schools in the area remain inaccessible due to presence of ERW.\xa0\n',
#  'Due to the conflict, 6.1 million people are in need of education assistance, including 5.8\xa0million children.\xa01.75 million children are out of school, and 1.35 million are at risk of dropping out. \xa0\xa0\xa0The lack of education is a source of mental distress for many children, who fear for their future.\xa0\n\nIn 2016, 255 children were killed in or near schools in Syria.\xa0\n\nAround one-third of schools nationwide are inaccessible due to conflict-induced damage.\xa0At least 87 attacks were recorded on schools in 2016: Aleppo, Rural Damascus, and al Hasakeh governorates are most affected. All sides\xa0are accused of having\xa0hit schools. \xa0\xa0\xa0\n',
#  '150,000 education staff have stopped work due to\xa0conflict, negatively impacting the entire education system in Syria. \xa0\n',
#  '1.75 million children are\xa0out of school, mainly due to the violence, insecurity, and children taking up work.\xa0\n\nOver 6,000 schools -\xa0one out of every three schools -\xa0has been damaged, destroyed, occupied by militants, or used as shelter. \xa0\xa0Only 50% of schools are functional; Ar-Raqqa, Aleppo, and\xa0Deir-ez-Zor governorates have\xa0the lowest percentage\xa0of functional schools.\n\nCritical shortages of learning materials and safe learning spaces are reported in besieged and hard-to-reach areas. In host communities, classes are overcrowded.\n\nSchools in besieged and hard-to-reach areas have been operating underground.\xa0However, the reported use of "bunker busting" missiles has discouraged many children from attending underground schools.\xa0Between 18 and 28 November 2016, six schools were hit by airstrikes in Idlib governorate.\n\nAround 24,500 children currently displaced in eastern Aleppo City are in need of education support. They\xa0have been out of school for more than two years.\xa0Many schools in the area remain inaccessible due to presence of ERW.\xa0\n',
#  'Due to the conflict, 6.1 million people are in need of education assistance, including 5.8\xa0million children.\xa01.75 million children are out of school, and 1.35 million are at risk of dropping out. \xa0\xa0\xa0The lack of education is a source of mental distress for many children, who fear for their future.\xa0\n\nIn 2016, 255 children were killed in or near schools in Syria.\xa0\n\nAround one-third of schools nationwide are inaccessible due to conflict-induced damage.\xa0At least 87 attacks were recorded on schools in 2016: Aleppo, Rural Damascus, and al Hasakeh governorates are most affected. All sides\xa0are accused of having\xa0hit schools. \xa0\xa0\xa0\n',
#  '150,000 education staff have stopped work due to\xa0conflict, negatively impacting the entire education system in Syria. \xa0\n',
#  '1.75 million children are\xa0out of school, mainly due to the violence, insecurity, and children taking up work.\xa0\n\nOver 6,000 schools -\xa0one out of every three schools -\xa0has been damaged, destroyed, occupied by militants, or used as shelter. \xa0\xa0Only 50% of schools are functional; Ar-Raqqa, Aleppo, and\xa0Deir-ez-Zor governorates have\xa0the lowest percentage\xa0of functional schools.\n\nCritical shortages of learning materials and safe learning spaces are reported in besieged and hard-to-reach areas. In host communities, classes are overcrowded.\n\nSchools in besieged and hard-to-reach areas have been operating underground.\xa0However, the reported use of "bunker busting" missiles has discouraged many children from attending underground schools.\xa0Between 18 and 28 November 2016, six schools were hit by airstrikes in Idlib governorate.\n\nAround 24,500 children currently displaced in eastern Aleppo City are in need of education support. They\xa0have been out of school for more than two years.\xa0Many schools in the area remain inaccessible due to presence of ERW.\xa0\n',
#  'Due to the conflict, 6.1 million people are in need of education assistance, including 5.8\xa0million children.\xa01.75 million children are out of school, and 1.35 million are at risk of dropping out. \xa0\xa0\xa0The lack of education is a source of mental distress for many children, who fear for their future.\xa0\n\nIn 2016, 255 children were killed in or near schools in Syria.\xa0\n\nAround one-third of schools nationwide are inaccessible due to conflict-induced damage.\xa0At least 87 attacks were recorded on schools in 2016: Aleppo, Rural Damascus, and al Hasakeh governorates are most affected. All sides\xa0are accused of having\xa0hit schools. \xa0\xa0\xa0\n',
#  '150,000 education staff have stopped work due to\xa0conflict, negatively impacting the entire education system in Syria. \xa0\n',
#  '1.75 million children are\xa0out of school, mainly due to the violence, insecurity, and children taking up work.\xa0\n\nOver 6,000 schools -\xa0one out of every three schools -\xa0has been damaged, destroyed, occupied by militants, or used as shelter. \xa0\xa0Only 50% of schools are functional; Ar-Raqqa, Aleppo, and\xa0Deir-ez-Zor governorates have\xa0the lowest percentage\xa0of functional schools.\n\nCritical shortages of learning materials and safe learning spaces are reported in besieged and hard-to-reach areas. In host communities, classes are overcrowded.\n\nSchools in besieged and hard-to-reach areas have been operating underground.\xa0However, the reported use of "bunker busting" missiles has discouraged many children from attending underground schools.\xa0Between 18 and 28 November 2016, six schools were hit by airstrikes in Idlib governorate.\n\nAround 24,500 children currently displaced in eastern Aleppo City are in need of education support. They\xa0have been out of school for more than two years.\xa0Many schools in the area remain inaccessible due to presence of ERW.\xa0\n',
#  'Due to the conflict, 6.1 million people are in need of education assistance, including 5.8\xa0million children.\xa01.75 million children are out of school, and 1.35 million are at risk of dropping out. \xa0\xa0\xa0The lack of education is a source of mental distress for many children, who fear for their future.\xa0\n\nIn 2016, 255 children were killed in or near schools in Syria.\xa0\n\nAround one-third of schools nationwide are inaccessible due to conflict-induced damage.\xa0At least 87 attacks were recorded on schools in 2016: Aleppo, Rural Damascus, and al Hasakeh governorates are most affected. All sides\xa0are accused of having\xa0hit schools. \xa0\xa0\xa0\n',
#  '150,000 education staff have stopped work due to\xa0conflict, negatively impacting the entire education system in Syria. \xa0\n',
#  '1.75 million children are\xa0out of school, mainly due to the violence, insecurity, and children taking up work.\xa0\n\nOver 6,000 schools -\xa0one out of every three schools -\xa0has been damaged, destroyed, occupied by militants, or used as shelter. \xa0\xa0Only 50% of schools are functional; Ar-Raqqa, Aleppo, and\xa0Deir-ez-Zor governorates have\xa0the lowest percentage\xa0of functional schools.\n\nCritical shortages of learning materials and safe learning spaces are reported in besieged and hard-to-reach areas. In host communities, classes are overcrowded.\n\nSchools in besieged and hard-to-reach areas have been operating underground.\xa0However, the reported use of "bunker busting" missiles has discouraged many children from attending underground schools.\xa0Between 18 and 28 November 2016, six schools were hit by airstrikes in Idlib governorate.\n\nAround 24,500 children currently displaced in eastern Aleppo City are in need of education support. They\xa0have been out of school for more than two years.\xa0Many schools in the area remain inaccessible due to presence of ERW.\xa0\n',
#  'Due to the conflict, 6.1 million people are in need of education assistance, including 5.8\xa0million children.\xa01.75 million children are out of school, and 1.35 million are at risk of dropping out. \xa0\xa0\xa0The lack of education is a source of mental distress for many children, who fear for their future.\xa0\n\nIn 2016, 255 children were killed in or near schools in Syria.\xa0\n\nAround one-third of schools nationwide are inaccessible due to conflict-induced damage.\xa0At least 87 attacks were recorded on schools in 2016: Aleppo, Rural Damascus, and al Hasakeh governorates are most affected. All sides\xa0are accused of having\xa0hit schools. \xa0\xa0\xa0\n',
#  '150,000 education staff have stopped work due to\xa0conflict, negatively impacting the entire education system in Syria. \xa0\n',
#  '1.75 million children are\xa0out of school, mainly due to the violence, insecurity, and children taking up work.\xa0\n\nOver 6,000 schools -\xa0one out of every three schools -\xa0has been damaged, destroyed, occupied by militants, or used as shelter. \xa0\xa0Only 50% of schools are functional; Ar-Raqqa, Aleppo, and\xa0Deir-ez-Zor governorates have\xa0the lowest percentage\xa0of functional schools.\n\nCritical shortages of learning materials and safe learning spaces are reported in besieged and hard-to-reach areas. In host communities, classes are overcrowded.\n\nSchools in besieged and hard-to-reach areas have been operating underground.\xa0However, the reported use of "bunker busting" missiles has discouraged many children from attending underground schools.\xa0Between 18 and 28 November 2016, six schools were hit by airstrikes in Idlib governorate.\n\nAround 24,500 children currently displaced in eastern Aleppo City are in need of education support. They\xa0have been out of school for more than two years.\xa0Many schools in the area remain inaccessible due to presence of ERW.\xa0\n',
#  'Due to the conflict, 6.1 million people are in need of education assistance, including 5.8\xa0million children.\xa01.75 million children are out of school, and 1.35 million are at risk of dropping out. \xa0\xa0\xa0The lack of education is a source of mental distress for many children, who fear for their future.\xa0\n\nIn 2016, 255 children were killed in or near schools in Syria.\xa0\n\nAround one-third of schools nationwide are inaccessible due to conflict-induced damage.\xa0At least 87 attacks were recorded on schools in 2016: Aleppo, Rural Damascus, and al Hasakeh governorates are most affected. All sides\xa0are accused of having\xa0hit schools. \xa0\xa0\xa0\n',
#  '150,000 education staff have stopped work due to\xa0conflict, negatively impacting the entire education system in Syria. \xa0\n',
#  '1.75 million children are\xa0out of school, mainly due to the violence, insecurity, and children taking up work.\xa0\n\nOver 6,000 schools -\xa0one out of every three schools -\xa0has been damaged, destroyed, occupied by militants, or used as shelter. \xa0\xa0Only 50% of schools are functional; Ar-Raqqa, Aleppo, and\xa0Deir-ez-Zor governorates have\xa0the lowest percentage\xa0of functional schools.\n\nCritical shortages of learning materials and safe learning spaces are reported in besieged and hard-to-reach areas. In host communities, classes are overcrowded.\n\nSchools in besieged and hard-to-reach areas have been operating underground.\xa0However, the reported use of "bunker busting" missiles has discouraged many children from attending underground schools.\xa0Between 18 and 28 November 2016, six schools were hit by airstrikes in Idlib governorate.\n\nAround 24,500 children currently displaced in eastern Aleppo City are in need of education support. They\xa0have been out of school for more than two years.\xa0Many schools in the area remain inaccessible due to presence of ERW.\xa0\n',
#  'Due to the conflict, 6.1 million people are in need of education assistance, including 5.8\xa0million children.\xa01.75 million children are out of school, and 1.35 million are at risk of dropping out. \xa0\xa0\xa0The lack of education is a source of mental distress for many children, who fear for their future.\xa0\n\nIn 2016, 255 children were killed in or near schools in Syria.\xa0\n\nAround one-third of schools nationwide are inaccessible due to conflict-induced damage.\xa0At least 87 attacks were recorded on schools in 2016: Aleppo, Rural Damascus, and al Hasakeh governorates are most affected. All sides\xa0are accused of having\xa0hit schools. \xa0\xa0\xa0\n',
#  '150,000 education staff have stopped work due to\xa0conflict, negatively impacting the entire education system in Syria. \xa0\n',
#  '1.75 million children are\xa0out of school, mainly due to the violence, insecurity, and children taking up work.\xa0\n\nOver 6,000 schools -\xa0one out of every three schools -\xa0has been damaged, destroyed, occupied by militants, or used as shelter. \xa0\xa0Only 50% of schools are functional; Ar-Raqqa, Aleppo, and\xa0Deir-ez-Zor governorates have\xa0the lowest percentage\xa0of functional schools.\n\nCritical shortages of learning materials and safe learning spaces are reported in besieged and hard-to-reach areas. In host communities, classes are overcrowded.\n\nSchools in besieged and hard-to-reach areas have been operating underground.\xa0However, the reported use of "bunker busting" missiles has discouraged many children from attending underground schools.\xa0Between 18 and 28 November 2016, six schools were hit by airstrikes in Idlib governorate.\n\nAround 24,500 children currently displaced in eastern Aleppo City are in need of education support. They\xa0have been out of school for more than two years.\xa0Many schools in the area remain inaccessible due to presence of ERW.\xa0\n',
#  'Due to the conflict, 6.1 million people are in need of education assistance, including 5.8\xa0million children.\xa01.75 million children are out of school, and 1.35 million are at risk of dropping out. \xa0\xa0\xa0The lack of education is a source of mental distress for many children, who fear for their future.\xa0\n\nIn 2016, 255 children were killed in or near schools in Syria.\xa0\n\nAround one-third of schools nationwide are inaccessible due to conflict-induced damage.\xa0At least 87 attacks were recorded on schools in 2016: Aleppo, Rural Damascus, and al Hasakeh governorates are most affected. All sides\xa0are accused of having\xa0hit schools. \xa0\xa0\xa0\n',
#  '150,000 education staff have stopped work due to\xa0conflict, negatively impacting the entire education system in Syria. \xa0\n',
#  '1.75 million children are\xa0out of school, mainly due to the violence, insecurity, and children taking up work.\xa0\n\nOver 6,000 schools -\xa0one out of every three schools -\xa0has been damaged, destroyed, occupied by militants, or used as shelter. \xa0\xa0Only 50% of schools are functional; Ar-Raqqa, Aleppo, and\xa0Deir-ez-Zor governorates have\xa0the lowest percentage\xa0of functional schools.\n\nCritical shortages of learning materials and safe learning spaces are reported in besieged and hard-to-reach areas. In host communities, classes are overcrowded.\n\nSchools in besieged and hard-to-reach areas have been operating underground.\xa0However, the reported use of "bunker busting" missiles has discouraged many children from attending underground schools.\xa0Between 18 and 28 November 2016, six schools were hit by airstrikes in Idlib governorate.\n\nAround 24,500 children currently displaced in eastern Aleppo City are in need of education support. They\xa0have been out of school for more than two years.\xa0Many schools in the area remain inaccessible due to presence of ERW.\xa0\n',
#  'Due to the conflict, 6.1 million people are in need of education assistance, including 5.8\xa0million children.\xa01.75 million children are out of school, and 1.35 million are at risk of dropping out. \xa0\xa0\xa0The lack of education is a source of mental distress for many children, who fear for their future.\xa0\n\nIn 2016, 255 children were killed in or near schools in Syria.\xa0\n\nAround one-third of schools nationwide are inaccessible due to conflict-induced damage.\xa0At least 87 attacks were recorded on schools in 2016: Aleppo, Rural Damascus, and al Hasakeh governorates are most affected. All sides\xa0are accused of having\xa0hit schools. \xa0\xa0\xa0\n',
#  '150,000 education staff have stopped work due to\xa0conflict, negatively impacting the entire education system in Syria. \xa0\n',
#  '1.75 million children are\xa0out of school, mainly due to the violence, insecurity, and children taking up work.\xa0\n\nOver 6,000 schools -\xa0one out of every three schools -\xa0has been damaged, destroyed, occupied by militants, or used as shelter. \xa0\xa0Only 50% of schools are functional; Ar-Raqqa, Aleppo, and\xa0Deir-ez-Zor governorates have\xa0the lowest percentage\xa0of functional schools.\n\nCritical shortages of learning materials and safe learning spaces are reported in besieged and hard-to-reach areas. In host communities, classes are overcrowded.\n\nSchools in besieged and hard-to-reach areas have been operating underground.\xa0However, the reported use of "bunker busting" missiles has discouraged many children from attending underground schools.\xa0Between 18 and 28 November 2016, six schools were hit by airstrikes in Idlib governorate.\n\nAround 24,500 children currently displaced in eastern Aleppo City are in need of education support. They\xa0have been out of school for more than two years.\xa0Many schools in the area remain inaccessible due to presence of ERW.\xa0\n',
#  'Due to the conflict, 6.1 million people are in need of education assistance, including 5.8\xa0million children.\xa01.75 million children are out of school, and 1.35 million are at risk of dropping out. \xa0\xa0\xa0The lack of education is a source of mental distress for many children, who fear for their future.\xa0\n\nIn 2016, 255 children were killed in or near schools in Syria.\xa0\n\nAround one-third of schools nationwide are inaccessible due to conflict-induced damage.\xa0At least 87 attacks were recorded on schools in 2016: Aleppo, Rural Damascus, and al Hasakeh governorates are most affected. All sides\xa0are accused of having\xa0hit schools. \xa0\xa0\xa0\n',
#  '150,000 education staff have stopped work due to\xa0conflict, negatively impacting the entire education system in Syria. \xa0\n',
#  '1.75 million children are\xa0out of school, mainly due to the violence, insecurity, and children taking up work.\xa0\n\nOver 6,000 schools -\xa0one out of every three schools -\xa0has been damaged, destroyed, occupied by militants, or used as shelter. \xa0\xa0Only 50% of schools are functional; Ar-Raqqa, Aleppo, and\xa0Deir-ez-Zor governorates have\xa0the lowest percentage\xa0of functional schools.\n\nCritical shortages of learning materials and safe learning spaces are reported in besieged and hard-to-reach areas. In host communities, classes are overcrowded.\n\nSchools in besieged and hard-to-reach areas have been operating underground.\xa0However, the reported use of "bunker busting" missiles has discouraged many children from attending underground schools.\xa0Between 18 and 28 November 2016, six schools were hit by airstrikes in Idlib governorate.\n\nAround 24,500 children currently displaced in eastern Aleppo City are in need of education support. They\xa0have been out of school for more than two years.\xa0Many schools in the area remain inaccessible due to presence of ERW.\xa0\n',
#  'Due to the conflict, 6.1 million people are in need of education assistance, including 5.8\xa0million children.\xa01.75 million children are out of school, and 1.35 million are at risk of dropping out. \xa0\xa0\xa0The lack of education is a source of mental distress for many children, who fear for their future.\xa0\n\nIn 2016, 255 children were killed in or near schools in Syria.\xa0\n\nAround one-third of schools nationwide are inaccessible due to conflict-induced damage.\xa0At least 87 attacks were recorded on schools in 2016: Aleppo, Rural Damascus, and al Hasakeh governorates are most affected. All sides\xa0are accused of having\xa0hit schools. \xa0\xa0\xa0\n',
#  '150,000 education staff have stopped work due to\xa0conflict, negatively impacting the entire education system in Syria. \xa0\n',
#  '1.75 million children are\xa0out of school, mainly due to the violence, insecurity, and children taking up work.\xa0\n\nOver 6,000 schools -\xa0one out of every three schools -\xa0has been damaged, destroyed, occupied by militants, or used as shelter. \xa0\xa0Only 50% of schools are functional; Ar-Raqqa, Aleppo, and\xa0Deir-ez-Zor governorates have\xa0the lowest percentage\xa0of functional schools.\n\nCritical shortages of learning materials and safe learning spaces are reported in besieged and hard-to-reach areas. In host communities, classes are overcrowded.\n\nSchools in besieged and hard-to-reach areas have been operating underground.\xa0However, the reported use of "bunker busting" missiles has discouraged many children from attending underground schools.\xa0Between 18 and 28 November 2016, six schools were hit by airstrikes in Idlib governorate.\n\nAround 24,500 children currently displaced in eastern Aleppo City are in need of education support. They\xa0have been out of school for more than two years.\xa0Many schools in the area remain inaccessible due to presence of ERW.\xa0\n',
#  'Due to the conflict, 6.1 million people are in need of education assistance, including 5.8\xa0million children.\xa01.75 million children are out of school, and 1.35 million are at risk of dropping out. \xa0\xa0\xa0The lack of education is a source of mental distress for many children, who fear for their future.\xa0\n\nIn 2016, 255 children were killed in or near schools in Syria.\xa0\n\nAround one-third of schools nationwide are inaccessible due to conflict-induced damage.\xa0At least 87 attacks were recorded on schools in 2016: Aleppo, Rural Damascus, and al Hasakeh governorates are most affected. All sides\xa0are accused of having\xa0hit schools. \xa0\xa0\xa0\n',
#  '150,000 education staff have stopped work due to\xa0conflict, negatively impacting the entire education system in Syria. \xa0\n',
#  '1.75 million children are\xa0out of school, mainly due to the violence, insecurity, and children taking up work.\xa0\n\nOver 6,000 schools -\xa0one out of every three schools -\xa0has been damaged, destroyed, occupied by militants, or used as shelter. \xa0\xa0Only 50% of schools are functional; Ar-Raqqa, Aleppo, and\xa0Deir-ez-Zor governorates have\xa0the lowest percentage\xa0of functional schools.\n\nCritical shortages of learning materials and safe learning spaces are reported in besieged and hard-to-reach areas. In host communities, classes are overcrowded.\n\nSchools in besieged and hard-to-reach areas have been operating underground.\xa0However, the reported use of "bunker busting" missiles has discouraged many children from attending underground schools.\xa0Between 18 and 28 November 2016, six schools were hit by airstrikes in Idlib governorate.\n\nAround 24,500 children currently displaced in eastern Aleppo City are in need of education support. They\xa0have been out of school for more than two years.\xa0Many schools in the area remain inaccessible due to presence of ERW.\xa0\n',
#  'Due to the conflict, 6.1 million people are in need of education assistance, including 5.8\xa0million children.\xa01.75 million children are out of school, and 1.35 million are at risk of dropping out. \xa0\xa0\xa0The lack of education is a source of mental distress for many children, who fear for their future.\xa0\n\nIn 2016, 255 children were killed in or near schools in Syria.\xa0\n\nAround one-third of schools nationwide are inaccessible due to conflict-induced damage.\xa0At least 87 attacks were recorded on schools in 2016: Aleppo, Rural Damascus, and al Hasakeh governorates are most affected. All sides\xa0are accused of having\xa0hit schools. \xa0\xa0\xa0\n',
#  '150,000 education staff have stopped work due to\xa0conflict, negatively impacting the entire education system in Syria. \xa0\n',
#  '1.75 million children are\xa0out of school, mainly due to the violence, insecurity, and children taking up work.\xa0\n\nOver 6,000 schools -\xa0one out of every three schools -\xa0has been damaged, destroyed, occupied by militants, or used as shelter. \xa0\xa0Only 50% of schools are functional; Ar-Raqqa, Aleppo, and\xa0Deir-ez-Zor governorates have\xa0the lowest percentage\xa0of functional schools.\n\nCritical shortages of learning materials and safe learning spaces are reported in besieged and hard-to-reach areas. In host communities, classes are overcrowded.\n\nSchools in besieged and hard-to-reach areas have been operating underground.\xa0However, the reported use of "bunker busting" missiles has discouraged many children from attending underground schools.\xa0Between 18 and 28 November 2016, six schools were hit by airstrikes in Idlib governorate.\n\nAround 24,500 children currently displaced in eastern Aleppo City are in need of education support. They\xa0have been out of school for more than two years.\xa0Many schools in the area remain inaccessible due to presence of ERW.\xa0\n',
#  'Due to the conflict, 6.1 million people are in need of education assistance, including 5.8\xa0million children.\xa01.75 million children are out of school, and 1.35 million are at risk of dropping out. \xa0\xa0\xa0The lack of education is a source of mental distress for many children, who fear for their future.\xa0\n\nIn 2016, 255 children were killed in or near schools in Syria.\xa0\n\nAround one-third of schools nationwide are inaccessible due to conflict-induced damage.\xa0At least 87 attacks were recorded on schools in 2016: Aleppo, Rural Damascus, and al Hasakeh governorates are most affected. All sides\xa0are accused of having\xa0hit schools. \xa0\xa0\xa0\n',
#  '150,000 education staff have stopped work due to\xa0conflict, negatively impacting the entire education system in Syria. \xa0\n',
#  '1.75 million children are\xa0out of school, mainly due to the violence, insecurity, and children taking up work.\xa0\n\nOver 6,000 schools -\xa0one out of every three schools -\xa0has been damaged, destroyed, occupied by militants, or used as shelter. \xa0\xa0Only 50% of schools are functional; Ar-Raqqa, Aleppo, and\xa0Deir-ez-Zor governorates have\xa0the lowest percentage\xa0of functional schools.\n\nCritical shortages of learning materials and safe learning spaces are reported in besieged and hard-to-reach areas. In host communities, classes are overcrowded.\n\nSchools in besieged and hard-to-reach areas have been operating underground.\xa0However, the reported use of "bunker busting" missiles has discouraged many children from attending underground schools.\xa0Between 18 and 28 November 2016, six schools were hit by airstrikes in Idlib governorate.\n\nAround 24,500 children currently displaced in eastern Aleppo City are in need of education support. They\xa0have been out of school for more than two years.\xa0Many schools in the area remain inaccessible due to presence of ERW.\xa0\n',
#  'Due to the conflict, 6.1 million people are in need of education assistance, including 5.8\xa0million children.\xa01.75 million children are out of school, and 1.35 million are at risk of dropping out. \xa0\xa0\xa0The lack of education is a source of mental distress for many children, who fear for their future.\xa0\n\nIn 2016, 255 children were killed in or near schools in Syria.\xa0\n\nAround one-third of schools nationwide are inaccessible due to conflict-induced damage.\xa0At least 87 attacks were recorded on schools in 2016: Aleppo, Rural Damascus, and al Hasakeh governorates are most affected. All sides\xa0are accused of having\xa0hit schools. \xa0\xa0\xa0\n',
#  '150,000 education staff have stopped work due to\xa0conflict, negatively impacting the entire education system in Syria. \xa0\n',
#  '1.75 million children are\xa0out of school, mainly due to the violence, insecurity, and children taking up work.\xa0\n\nOver 6,000 schools -\xa0one out of every three schools -\xa0has been damaged, destroyed, occupied by militants, or used as shelter. \xa0\xa0Only 50% of schools are functional; Ar-Raqqa, Aleppo, and\xa0Deir-ez-Zor governorates have\xa0the lowest percentage\xa0of functional schools.\n\nCritical shortages of learning materials and safe learning spaces are reported in besieged and hard-to-reach areas. In host communities, classes are overcrowded.\n\nSchools in besieged and hard-to-reach areas have been operating underground.\xa0However, the reported use of "bunker busting" missiles has discouraged many children from attending underground schools.\xa0Between 18 and 28 November 2016, six schools were hit by airstrikes in Idlib governorate.\n\nAround 24,500 children currently displaced in eastern Aleppo City are in need of education support. They\xa0have been out of school for more than two years.\xa0Many schools in the area remain inaccessible due to presence of ERW.\xa0\n',
#  'Due to the conflict, 6.1 million people are in need of education assistance, including 5.8\xa0million children.\xa01.75 million children are out of school, and 1.35 million are at risk of dropping out. \xa0\xa0\xa0The lack of education is a source of mental distress for many children, who fear for their future.\xa0\n\nIn 2016, 255 children were killed in or near schools in Syria.\xa0\n\nAround one-third of schools nationwide are inaccessible due to conflict-induced damage.\xa0At least 87 attacks were recorded on schools in 2016: Aleppo, Rural Damascus, and al Hasakeh governorates are most affected. All sides\xa0are accused of having\xa0hit schools. \xa0\xa0\xa0\n',
#  '150,000 education staff have stopped work due to\xa0conflict, negatively impacting the entire education system in Syria. \xa0\n',
#  '1.75 million children are\xa0out of school, mainly due to the violence, insecurity, and children taking up work.\xa0\n\nOver 6,000 schools -\xa0one out of every three schools -\xa0has been damaged, destroyed, occupied by militants, or used as shelter. \xa0\xa0Only 50% of schools are functional; Ar-Raqqa, Aleppo, and\xa0Deir-ez-Zor governorates have\xa0the lowest percentage\xa0of functional schools.\n\nCritical shortages of learning materials and safe learning spaces are reported in besieged and hard-to-reach areas. In host communities, classes are overcrowded.\n\nSchools in besieged and hard-to-reach areas have been operating underground.\xa0However, the reported use of "bunker busting" missiles has discouraged many children from attending underground schools.\xa0Between 18 and 28 November 2016, six schools were hit by airstrikes in Idlib governorate.\n\nAround 24,500 children currently displaced in eastern Aleppo City are in need of education support. They\xa0have been out of school for more than two years.\xa0Many schools in the area remain inaccessible due to presence of ERW.\xa0\n',
#  'Due to the conflict, 6.1 million people are in need of education assistance, including 5.8\xa0million children.\xa01.75 million children are out of school, and 1.35 million are at risk of dropping out. \xa0\xa0\xa0The lack of education is a source of mental distress for many children, who fear for their future.\xa0\n\nIn 2016, 255 children were killed in or near schools in Syria.\xa0\n\nAround one-third of schools nationwide are inaccessible due to conflict-induced damage.\xa0At least 87 attacks were recorded on schools in 2016: Aleppo, Rural Damascus, and al Hasakeh governorates are most affected. All sides\xa0are accused of having\xa0hit schools. \xa0\xa0\xa0\n',
#  '150,000 education staff have stopped work due to\xa0conflict, negatively impacting the entire education system in Syria. \xa0\n',
#  '1.75 million children are\xa0out of school, mainly due to the violence, insecurity, and children taking up work.\xa0\n\nOver 6,000 schools -\xa0one out of every three schools -\xa0has been damaged, destroyed, occupied by militants, or used as shelter. \xa0\xa0Only 50% of schools are functional; Ar-Raqqa, Aleppo, and\xa0Deir-ez-Zor governorates have\xa0the lowest percentage\xa0of functional schools.\n\nCritical shortages of learning materials and safe learning spaces are reported in besieged and hard-to-reach areas. In host communities, classes are overcrowded.\n\nSchools in besieged and hard-to-reach areas have been operating underground.\xa0However, the reported use of "bunker busting" missiles has discouraged many children from attending underground schools.\xa0Between 18 and 28 November 2016, six schools were hit by airstrikes in Idlib governorate.\n\nAround 24,500 children currently displaced in eastern Aleppo City are in need of education support. They\xa0have been out of school for more than two years.\xa0Many schools in the area remain inaccessible due to presence of ERW.\xa0\n',
#  'Due to the conflict, 6.1 million people are in need of education assistance, including 5.8\xa0million children.\xa01.75 million children are out of school, and 1.35 million are at risk of dropping out. \xa0\xa0\xa0The lack of education is a source of mental distress for many children, who fear for their future.\xa0\n\nIn 2016, 255 children were killed in or near schools in Syria.\xa0\n\nAround one-third of schools nationwide are inaccessible due to conflict-induced damage.\xa0At least 87 attacks were recorded on schools in 2016: Aleppo, Rural Damascus, and al Hasakeh governorates are most affected. All sides\xa0are accused of having\xa0hit schools. \xa0\xa0\xa0\n',
#  '150,000 education staff have stopped work due to\xa0conflict, negatively impacting the entire education system in Syria. \xa0\n',
#  '1.75 million children are\xa0out of school, mainly due to the violence, insecurity, and children taking up work.\xa0\n\nOver 6,000 schools -\xa0one out of every three schools -\xa0has been damaged, destroyed, occupied by militants, or used as shelter. \xa0\xa0Only 50% of schools are functional; Ar-Raqqa, Aleppo, and\xa0Deir-ez-Zor governorates have\xa0the lowest percentage\xa0of functional schools.\n\nCritical shortages of learning materials and safe learning spaces are reported in besieged and hard-to-reach areas. In host communities, classes are overcrowded.\n\nSchools in besieged and hard-to-reach areas have been operating underground.\xa0However, the reported use of "bunker busting" missiles has discouraged many children from attending underground schools.\xa0Between 18 and 28 November 2016, six schools were hit by airstrikes in Idlib governorate.\n\nAround 24,500 children currently displaced in eastern Aleppo City are in need of education support. They\xa0have been out of school for more than two years.\xa0Many schools in the area remain inaccessible due to presence of ERW.\xa0\n',
#  'Due to the conflict, 6.1 million people are in need of education assistance, including 5.8\xa0million children.\xa01.75 million children are out of school, and 1.35 million are at risk of dropping out. \xa0\xa0\xa0The lack of education is a source of mental distress for many children, who fear for their future.\xa0\n\nIn 2016, 255 children were killed in or near schools in Syria.\xa0\n\nAround one-third of schools nationwide are inaccessible due to conflict-induced damage.\xa0At least 87 attacks were recorded on schools in 2016: Aleppo, Rural Damascus, and al Hasakeh governorates are most affected. All sides\xa0are accused of having\xa0hit schools. \xa0\xa0\xa0\n',
#  '150,000 education staff have stopped work due to\xa0conflict, negatively impacting the entire education system in Syria. \xa0\n',
#  '1.75 million children are\xa0out of school, mainly due to the violence, insecurity, and children taking up work.\xa0\n\nOver 6,000 schools -\xa0one out of every three schools -\xa0has been damaged, destroyed, occupied by militants, or used as shelter. \xa0\xa0Only 50% of schools are functional; Ar-Raqqa, Aleppo, and\xa0Deir-ez-Zor governorates have\xa0the lowest percentage\xa0of functional schools.\n\nCritical shortages of learning materials and safe learning spaces are reported in besieged and hard-to-reach areas. In host communities, classes are overcrowded.\n\nSchools in besieged and hard-to-reach areas have been operating underground.\xa0However, the reported use of "bunker busting" missiles has discouraged many children from attending underground schools.\xa0Between 18 and 28 November 2016, six schools were hit by airstrikes in Idlib governorate.\n\nAround 24,500 children currently displaced in eastern Aleppo City are in need of education support. They\xa0have been out of school for more than two years.\xa0Many schools in the area remain inaccessible due to presence of ERW.\xa0\n',
#  'Due to the conflict, 6.1 million people are in need of education assistance, including 5.8\xa0million children.\xa01.75 million children are out of school, and 1.35 million are at risk of dropping out. \xa0\xa0\xa0The lack of education is a source of mental distress for many children, who fear for their future.\xa0\n\nIn 2016, 255 children were killed in or near schools in Syria.\xa0\n\nAround one-third of schools nationwide are inaccessible due to conflict-induced damage.\xa0At least 87 attacks were recorded on schools in 2016: Aleppo, Rural Damascus, and al Hasakeh governorates are most affected. All sides\xa0are accused of having\xa0hit schools. \xa0\xa0\xa0\n',
#  '150,000 education staff have stopped work due to\xa0conflict, negatively impacting the entire education system in Syria. \xa0\n',
#  '1.75 million children are\xa0out of school, mainly due to the violence, insecurity, and children taking up work.\xa0\n\nOver 6,000 schools -\xa0one out of every three schools -\xa0has been damaged, destroyed, occupied by militants, or used as shelter. \xa0\xa0Only 50% of schools are functional; Ar-Raqqa, Aleppo, and\xa0Deir-ez-Zor governorates have\xa0the lowest percentage\xa0of functional schools.\n\nCritical shortages of learning materials and safe learning spaces are reported in besieged and hard-to-reach areas. In host communities, classes are overcrowded.\n\nSchools in besieged and hard-to-reach areas have been operating underground.\xa0However, the reported use of "bunker busting" missiles has discouraged many children from attending underground schools.\xa0Between 18 and 28 November 2016, six schools were hit by airstrikes in Idlib governorate.\n\nAround 24,500 children currently displaced in eastern Aleppo City are in need of education support. They\xa0have been out of school for more than two years.\xa0Many schools in the area remain inaccessible due to presence of ERW.\xa0\n',
#  'Due to the conflict, 6.1 million people are in need of education assistance, including 5.8\xa0million children.\xa01.75 million children are out of school, and 1.35 million are at risk of dropping out. \xa0\xa0\xa0The lack of education is a source of mental distress for many children, who fear for their future.\xa0\n\nIn 2016, 255 children were killed in or near schools in Syria.\xa0\n\nAround one-third of schools nationwide are inaccessible due to conflict-induced damage.\xa0At least 87 attacks were recorded on schools in 2016: Aleppo, Rural Damascus, and al Hasakeh governorates are most affected. All sides\xa0are accused of having\xa0hit schools. \xa0\xa0\xa0\n',
#  '150,000 education staff have stopped work due to\xa0conflict, negatively impacting the entire education system in Syria. \xa0\n',
#  '1.75 million children are\xa0out of school, mainly due to the violence, insecurity, and children taking up work.\xa0\n\nOver 6,000 schools -\xa0one out of every three schools -\xa0has been damaged, destroyed, occupied by militants, or used as shelter. \xa0\xa0Only 50% of schools are functional; Ar-Raqqa, Aleppo, and\xa0Deir-ez-Zor governorates have\xa0the lowest percentage\xa0of functional schools.\n\nCritical shortages of learning materials and safe learning spaces are reported in besieged and hard-to-reach areas. In host communities, classes are overcrowded.\n\nSchools in besieged and hard-to-reach areas have been operating underground.\xa0However, the reported use of "bunker busting" missiles has discouraged many children from attending underground schools.\xa0Between 18 and 28 November 2016, six schools were hit by airstrikes in Idlib governorate.\n\nAround 24,500 children currently displaced in eastern Aleppo City are in need of education support. They\xa0have been out of school for more than two years.\xa0Many schools in the area remain inaccessible due to presence of ERW.\xa0\n',
#  'Due to the conflict, 6.1 million people are in need of education assistance, including 5.8\xa0million children.\xa01.75 million children are out of school, and 1.35 million are at risk of dropping out. \xa0\xa0\xa0The lack of education is a source of mental distress for many children, who fear for their future.\xa0\n\nIn 2016, 255 children were killed in or near schools in Syria.\xa0\n\nAround one-third of schools nationwide are inaccessible due to conflict-induced damage.\xa0At least 87 attacks were recorded on schools in 2016: Aleppo, Rural Damascus, and al Hasakeh governorates are most affected. All sides\xa0are accused of having\xa0hit schools. \xa0\xa0\xa0\n',
#  '150,000 education staff have stopped work due to\xa0conflict, negatively impacting the entire education system in Syria. \xa0\n',
#  '1.75 million children are\xa0out of school, mainly due to the violence, insecurity, and children taking up work.\xa0\n\nOver 6,000 schools -\xa0one out of every three schools -\xa0has been damaged, destroyed, occupied by militants, or used as shelter. \xa0\xa0Only 50% of schools are functional; Ar-Raqqa, Aleppo, and\xa0Deir-ez-Zor governorates have\xa0the lowest percentage\xa0of functional schools.\n\nCritical shortages of learning materials and safe learning spaces are reported in besieged and hard-to-reach areas. In host communities, classes are overcrowded.\n\nSchools in besieged and hard-to-reach areas have been operating underground.\xa0However, the reported use of "bunker busting" missiles has discouraged many children from attending underground schools.\xa0Between 18 and 28 November 2016, six schools were hit by airstrikes in Idlib governorate.\n\nAround 24,500 children currently displaced in eastern Aleppo City are in need of education support. They\xa0have been out of school for more than two years.\xa0Many schools in the area remain inaccessible due to presence of ERW.\xa0\n',
#  'Due to the conflict, 6.1 million people are in need of education assistance, including 5.8\xa0million children.\xa01.75 million children are out of school, and 1.35 million are at risk of dropping out. \xa0\xa0\xa0The lack of education is a source of mental distress for many children, who fear for their future.\xa0\n\nIn 2016, 255 children were killed in or near schools in Syria.\xa0\n\nAround one-third of schools nationwide are inaccessible due to conflict-induced damage.\xa0At least 87 attacks were recorded on schools in 2016: Aleppo, Rural Damascus, and al Hasakeh governorates are most affected. All sides\xa0are accused of having\xa0hit schools. \xa0\xa0\xa0\n',
#  '150,000 education staff have stopped work due to\xa0conflict, negatively impacting the entire education system in Syria. \xa0\n',
#  '1.75 million children are\xa0out of school, mainly due to the violence, insecurity, and children taking up work.\xa0\n\nOver 6,000 schools -\xa0one out of every three schools -\xa0has been damaged, destroyed, occupied by militants, or used as shelter. \xa0\xa0Only 50% of schools are functional; Ar-Raqqa, Aleppo, and\xa0Deir-ez-Zor governorates have\xa0the lowest percentage\xa0of functional schools.\n\nCritical shortages of learning materials and safe learning spaces are reported in besieged and hard-to-reach areas. In host communities, classes are overcrowded.\n\nSchools in besieged and hard-to-reach areas have been operating underground.\xa0However, the reported use of "bunker busting" missiles has discouraged many children from attending underground schools.\xa0Between 18 and 28 November 2016, six schools were hit by airstrikes in Idlib governorate.\n\nAround 24,500 children currently displaced in eastern Aleppo City are in need of education support. They\xa0have been out of school for more than two years.\xa0Many schools in the area remain inaccessible due to presence of ERW.\xa0\n',
#  'Due to the conflict, 6.1 million people are in need of education assistance, including 5.8\xa0million children.\xa01.75 million children are out of school, and 1.35 million are at risk of dropping out. \xa0\xa0\xa0The lack of education is a source of mental distress for many children, who fear for their future.\xa0\n\nIn 2016, 255 children were killed in or near schools in Syria.\xa0\n\nAround one-third of schools nationwide are inaccessible due to conflict-induced damage.\xa0At least 87 attacks were recorded on schools in 2016: Aleppo, Rural Damascus, and al Hasakeh governorates are most affected. All sides\xa0are accused of having\xa0hit schools. \xa0\xa0\xa0\n',
#  '150,000 education staff have stopped work due to\xa0conflict, negatively impacting the entire education system in Syria. \xa0\n',
#  '1.75 million children are\xa0out of school, mainly due to the violence, insecurity, and children taking up work.\xa0\n\nOver 6,000 schools -\xa0one out of every three schools -\xa0has been damaged, destroyed, occupied by militants, or used as shelter. \xa0\xa0Only 50% of schools are functional; Ar-Raqqa, Aleppo, and\xa0Deir-ez-Zor governorates have\xa0the lowest percentage\xa0of functional schools.\n\nCritical shortages of learning materials and safe learning spaces are reported in besieged and hard-to-reach areas. In host communities, classes are overcrowded.\n\nSchools in besieged and hard-to-reach areas have been operating underground.\xa0However, the reported use of "bunker busting" missiles has discouraged many children from attending underground schools.\xa0Between 18 and 28 November 2016, six schools were hit by airstrikes in Idlib governorate.\n\nAround 24,500 children currently displaced in eastern Aleppo City are in need of education support. They\xa0have been out of school for more than two years.\xa0Many schools in the area remain inaccessible due to presence of ERW.\xa0\n',
#  'Due to the conflict, 6.1 million people are in need of education assistance, including 5.8\xa0million children.\xa01.75 million children are out of school, and 1.35 million are at risk of dropping out. \xa0\xa0\xa0The lack of education is a source of mental distress for many children, who fear for their future.\xa0\n\nIn 2016, 255 children were killed in or near schools in Syria.\xa0\n\nAround one-third of schools nationwide are inaccessible due to conflict-induced damage.\xa0At least 87 attacks were recorded on schools in 2016: Aleppo, Rural Damascus, and al Hasakeh governorates are most affected. All sides\xa0are accused of having\xa0hit schools. \xa0\xa0\xa0\n',
#  '150,000 education staff have stopped work due to\xa0conflict, negatively impacting the entire education system in Syria. \xa0\n',
#  '1.75 million children are\xa0out of school, mainly due to the violence, insecurity, and children taking up work.\xa0\n\nOver 6,000 schools -\xa0one out of every three schools -\xa0has been damaged, destroyed, occupied by militants, or used as shelter. \xa0\xa0Only 50% of schools are functional; Ar-Raqqa, Aleppo, and\xa0Deir-ez-Zor governorates have\xa0the lowest percentage\xa0of functional schools.\n\nCritical shortages of learning materials and safe learning spaces are reported in besieged and hard-to-reach areas. In host communities, classes are overcrowded.\n\nSchools in besieged and hard-to-reach areas have been operating underground.\xa0However, the reported use of "bunker busting" missiles has discouraged many children from attending underground schools.\xa0Between 18 and 28 November 2016, six schools were hit by airstrikes in Idlib governorate.\n\nAround 24,500 children currently displaced in eastern Aleppo City are in need of education support. They\xa0have been out of school for more than two years.\xa0Many schools in the area remain inaccessible due to presence of ERW.\xa0\n',
#  'Due to the conflict, 6.1 million people are in need of education assistance, including 5.8\xa0million children.\xa01.75 million children are out of school, and 1.35 million are at risk of dropping out. \xa0\xa0\xa0The lack of education is a source of mental distress for many children, who fear for their future.\xa0\n\nIn 2016, 255 children were killed in or near schools in Syria.\xa0\n\nAround one-third of schools nationwide are inaccessible due to conflict-induced damage.\xa0At least 87 attacks were recorded on schools in 2016: Aleppo, Rural Damascus, and al Hasakeh governorates are most affected. All sides\xa0are accused of having\xa0hit schools. \xa0\xa0\xa0\n',
#  '150,000 education staff have stopped work due to\xa0conflict, negatively impacting the entire education system in Syria. \xa0\n',
#  '1.75 million children are\xa0out of school, mainly due to the violence, insecurity, and children taking up work.\xa0\n\nOver 6,000 schools -\xa0one out of every three schools -\xa0has been damaged, destroyed, occupied by militants, or used as shelter. \xa0\xa0Only 50% of schools are functional; Ar-Raqqa, Aleppo, and\xa0Deir-ez-Zor governorates have\xa0the lowest percentage\xa0of functional schools.\n\nCritical shortages of learning materials and safe learning spaces are reported in besieged and hard-to-reach areas. In host communities, classes are overcrowded.\n\nSchools in besieged and hard-to-reach areas have been operating underground.\xa0However, the reported use of "bunker busting" missiles has discouraged many children from attending underground schools.\xa0Between 18 and 28 November 2016, six schools were hit by airstrikes in Idlib governorate.\n\nAround 24,500 children currently displaced in eastern Aleppo City are in need of education support. They\xa0have been out of school for more than two years.\xa0Many schools in the area remain inaccessible due to presence of ERW.\xa0\n',
#  'Due to the conflict, 6.1 million people are in need of education assistance, including 5.8\xa0million children.\xa01.75 million children are out of school, and 1.35 million are at risk of dropping out. \xa0\xa0\xa0The lack of education is a source of mental distress for many children, who fear for their future.\xa0\n\nIn 2016, 255 children were killed in or near schools in Syria.\xa0\n\nAround one-third of schools nationwide are inaccessible due to conflict-induced damage.\xa0At least 87 attacks were recorded on schools in 2016: Aleppo, Rural Damascus, and al Hasakeh governorates are most affected. All sides\xa0are accused of having\xa0hit schools. \xa0\xa0\xa0\n']

# %%
#show duplicates
from pprint import pprint

c=0
for k,v in cats.items():
    print(k + ' ' + str(len((set(v)))))
    c+=len((set(v)))
           
print(c)
# Out:
# Displacement 124
# Humanitarian access 80
# Shelter and NFIs 48
# WASH 75
# Health 107
# Protection 151
# Education 47
# Politics and security 119
# Food security and livelihoods 154
# Nutrition 41
# 946

# %%
#create random sampling groups
#TODO: should we do uniform random sampling per group or a whole scale random draw?

#return dicts with {sect: setted list of entries}
def gen_tt(corpus):
    test = {}
    train = {}

    #add corpus to test and train
    for k in corpus.keys():
        test[k] = None
        train[k] = None

    for k,v in corpus.items():
        random.shuffle(v)

        setv = list(set(v))
        len_test = int(len(setv)*.3)

        test[k] = setv[:len_test]
        train[k] = setv[len_test:]

    return train, test

train, test = gen_tt(cats)
#     #check lengths
#     for k in train.keys():
#         print(k + ' train : ' + str(len(train[k])))
#         print(k + ' test : ' + str(len(test[k])))

# %%
#test sampling (if we do 70:30)

d = {
    'cat1': [random.randint(0,100) for i in range(100)],
    'cat2': [random.randint(0,100) for i in range(150)]
}

test = {}
train = {}

#add cats to test and train
for k in d.keys():
    test[k] = None
    train[k] = None

for k,v in d.items():
    len_test = int(len(v)*.3)
    print(len(v)*.3)
    
    test[k] = v[:len_test]
    train[k] = v[len_test:]
    
print(len(test))
print(len(train))
# Out:
# 45.0
# 30.0
# 2
# 2

# %%
#start building our model
#train and test are just subsets of cats (for now)

#make a feature with word presence
#TODO: what's python func?
all_words = []
for k,v in cats.items():
    for e in list(set(v)):
        for w in e.split(' '):
            all_words.append(w.lower())

freq_words = nltk.FreqDist(all_words)

def document_features(document):
#     if type(document) == list:
#         #TODO: func
#         grp = ''
#         for l in document:
#             for w in l:
#                 grp += w
#         document = grp
                
    uniq_doc = set(document.split(' '))
    features = {}
    for word in list(freq_words.keys())[:2000]:
        features['contains(%s)' % word] = (word in uniq_doc)
    return features

#convert dicts into list of tuples we need
#TODO: func
train_merge = []
test_merge = []

for k,v in train.items():
    for i in v:
        train_merge.append((k,i))

for k,v in test.items():
    for i in v:
        test_merge.append((k,i))

        
print(len(test_merge))

wp_train = [(document_features(v), k) for k,v in train_merge]
wp_test = [(document_features(v), k) for k,v in test_merge]

nb_class = nltk.NaiveBayesClassifier.train(wp_train)

# wp_test[0]
# Out:
# 281

# %%
#results

#from just raw, unrefined features and 200 words: 0.398576512455516

nb_class.show_most_informative_features(100)
# Out:
# Most Informative Features
#        contains(primary) = True           Educat : Food s =     35.3 : 1.0
#      contains(political) = True           Politi : Food s =     25.2 : 1.0
#         contains(houses) = True           Shelte : WASH   =     15.9 : 1.0
#       contains(outbreak) = True           Health : Politi =     14.5 : 1.0
#         contains(asylum) = True           Displa : Food s =     14.5 : 1.0
#     contains(registered) = True           Displa : Food s =     14.1 : 1.0
#          contains(until) = True           Politi : Protec =     13.0 : 1.0
#          contains(women) = True           Protec : Politi =     13.0 : 1.0
#           contains(army) = True           Politi : Food s =     11.5 : 1.0
#            contains(but) = True           Politi : Shelte =     11.1 : 1.0
#             contains(17) = True           Politi : Food s =     10.7 : 1.0
#       contains(fighters) = True           Politi : Displa =     10.0 : 1.0
#          contains(rains) = True           Shelte : Health =      9.4 : 1.0
#      contains(emergency) = True           Nutrit : Protec =      9.3 : 1.0
#            contains(use) = True           Protec : Displa =      8.0 : 1.0
#         contains(public) = True           Shelte : Displa =      7.5 : 1.0
#            contains(off) = True           Shelte : Food s =      7.3 : 1.0
#          contains(times) = True             WASH : Protec =      7.3 : 1.0
#      contains(buildings) = True           Shelte : Protec =      7.1 : 1.0
#      contains(long-term) = True           Displa : Protec =      6.9 : 1.0
#        contains(sources) = True             WASH : Humani =      6.7 : 1.0
#      contains(agreement) = True           Politi : Humani =      6.5 : 1.0
#           contains(cuts) = True             WASH : Food s =      6.1 : 1.0
#           contains(down) = True           Nutrit : Food s =      6.1 : 1.0
#       contains(physical) = True           Protec : Food s =      5.8 : 1.0
#   contains(inaccessible) = True           Humani : Food s =      5.7 : 1.0
#          contains(time,) = True           Humani : Food s =      5.7 : 1.0
#          contains(camp,) = True           Displa : Protec =      5.6 : 1.0
#           contains(less) = True             WASH : Displa =      5.5 : 1.0
#           contains(toll) = True           Politi : Protec =      5.5 : 1.0
#          contains(joint) = True           Politi : Protec =      5.5 : 1.0
#          contains(raids) = True           Politi : Protec =      5.5 : 1.0
# contains(implementation) = True           Politi : Protec =      5.5 : 1.0
#            contains(way) = True           Educat : Food s =      5.3 : 1.0
#            contains(the) = False          Nutrit : Food s =      5.2 : 1.0
#         contains(report) = True           Protec : Displa =      5.2 : 1.0
#          contains(needs) = True           Shelte : Food s =      5.2 : 1.0
#       contains(tensions) = True           Politi : Displa =      5.2 : 1.0
#          contains(worst) = True           Shelte : Protec =      5.1 : 1.0
#       contains(released) = True           Protec : Food s =      5.1 : 1.0
#         contains(unable) = True           Educat : Humani =      5.0 : 1.0
#           contains(some) = True           Educat : Nutrit =      5.0 : 1.0
#      contains(increased) = True           Food s : Shelte =      4.8 : 1.0
#              contains(2) = True           Politi : Protec =      4.8 : 1.0
#              contains(3) = True           Educat : WASH   =      4.8 : 1.0
#          contains(found) = True           Nutrit : Politi =      4.7 : 1.0
#     contains(reportedly) = True           Politi : Humani =      4.7 : 1.0
#  contains(contamination) = True             WASH : Protec =      4.6 : 1.0
#          contains(1,500) = True           Displa : Food s =      4.5 : 1.0
#   contains(cross-border) = True           Humani : Food s =      4.5 : 1.0
#          contains(large) = True           Politi : WASH   =      4.4 : 1.0
#        contains(private) = True           Shelte : Food s =      4.4 : 1.0
#           contains(cash) = True           Food s : Protec =      4.3 : 1.0
#      contains(resources) = True           Food s : Protec =      4.3 : 1.0
#            contains(old) = True           Nutrit : Health =      4.2 : 1.0
#           contains(east) = True           Shelte : Displa =      4.2 : 1.0
#        contains(heavily) = True           Food s : Displa =      4.0 : 1.0
#        contains(reports) = True           Protec : Food s =      4.0 : 1.0
#     contains(purchasing) = True           Food s : Politi =      3.9 : 1.0
#          contains(first) = True           Politi : Food s =      3.8 : 1.0
#             contains(el) = True           Politi : Food s =      3.8 : 1.0
#         contains(guards) = True           Politi : Protec =      3.8 : 1.0
#           contains(time) = True           Protec : Food s =      3.7 : 1.0
#           contains(move) = True           Educat : Health =      3.7 : 1.0
#       contains(register) = True           Displa : Protec =      3.6 : 1.0
#         contains(stands) = True           Nutrit : Food s =      3.6 : 1.0
#         contains(desert) = True           Nutrit : Food s =      3.6 : 1.0
#      contains(2017.
#
#
# ) = True           Nutrit : Food s =      3.6 : 1.0
#          contains(daily) = True           Nutrit : Food s =      3.6 : 1.0
#            contains(air) = True           Humani : Displa =      3.6 : 1.0
#        contains(selling) = True           Food s : Protec =      3.6 : 1.0
#         contains(urgent) = True           Nutrit : Protec =      3.6 : 1.0
#         contains(adults) = True           Nutrit : Protec =      3.6 : 1.0
#            contains(3.1) = True           Nutrit : Protec =      3.6 : 1.0
#            contains(
# ) = True           Nutrit : Protec =      3.6 : 1.0
#       contains(killings) = True           Protec : Displa =      3.6 : 1.0
#         contains(influx) = True           Displa : Politi =      3.5 : 1.0
#          contains(other) = True           Politi : Shelte =      3.5 : 1.0
#      contains(shelters,) = True           Shelte : Displa =      3.5 : 1.0
#           contains(line) = True           Humani : Politi =      3.5 : 1.0
#     contains(connecting) = True           Humani : Politi =      3.5 : 1.0
#          contains(being) = True           Politi : WASH   =      3.4 : 1.0
#          contains(built) = True             WASH : Protec =      3.3 : 1.0
#   contains(deteriorated) = True           Educat : Food s =      3.2 : 1.0
#            contains(1.6) = True           Educat : Food s =      3.2 : 1.0
#           contains(lost) = True           Politi : WASH   =      3.2 : 1.0
#           contains(yet.) = True           Educat : Protec =      3.1 : 1.0
#            contains(250) = True           Educat : Protec =      3.1 : 1.0
# contains(discrimination,) = True           Educat : Protec =      3.1 : 1.0
#       contains(attended) = True           Educat : Protec =      3.1 : 1.0
#         contains(secure) = True           Educat : Protec =      3.1 : 1.0
#        contains(quality) = True           Educat : Health =      3.1 : 1.0
#   contains(construction) = True           Shelte : Food s =      3.1 : 1.0
#        contains(arrival) = True           Shelte : Food s =      3.1 : 1.0
#      contains(disasters) = True           Shelte : Food s =      3.1 : 1.0
#         contains(copper) = True           Shelte : Food s =      3.1 : 1.0
#      contains(people in) = True           Shelte : Food s =      3.1 : 1.0
#        contains(state's) = True           Shelte : Food s =      3.1 : 1.0
#           contains(done) = True           Shelte : Food s =      3.1 : 1.0
#        contains(largely) = True           Politi : Displa =      3.1 : 1.0

# %%
# ['contains(hit)',
#  'contains(down)',
#  'contains(being)',
#  'contains(member.)',
#  'contains(17)',
#  'contains(other)',
#  'contains(air)',
#  'contains(redirect,)',
#  'contains(released)',
#  'contains(independence)',
#  'contains(until)',
#  'contains(the)']

# [k for k,v in wp_train[100][0].items() if v is True]

wp_train[100][1]
# Out:
# 'Humanitarian access'

# %%
for k,v in train.items():
    print(k)
    print(v)
    break
# Out:
# Displacement
# ["By 31 January, there were an estimated 1.9\xa0million IDPs across six states\xa0in northeast Nigeria,\xa0an increase of 7% from the December assessment. The overall figure includes 1.5\xa0million\xa0in\xa0Borno,\xa0147,000\xa0in Adamawa, and 113,000 in Yobe. 29.5%\xa0of these IDPs have been displaced in 2016. 97% have been displaced due to the\xa0BH\xa0insurgency, and 3% due to communal clashes. 86.8% of IDPs originate from Borno, 5.7% from Adamawa, and 4.2% from Yobe.\xa0\xa0By the end of February it was reported that IDPs were increasingly moving from Maiduguri to newly accessible LGAs.\xa0\xa0This includes the 100 families that were returning per day to Damasak LGA in February.\xa0\n\nCounter insurgency operations in Chibok, Damboa, Gwoza, Kala/Balge, Mafa and Monguno LGAs in Borno state Between 25 February and 1 March, at least 7,000 people were displaced from Chibok in Borno state due to renewed BH attacks. \xa0Between 27 January and 10 February, military operations forced an estimated 8,000 people to flee Marte and 3,000 from Gwoza LGAs in Borno state. \xa0Between December 2016 and early February,\xa0a reported 10,000 people were forced to flee intercommunal\xa0violence in\xa0Ardo Kola, Gassol, and Lau LGAs in Taraba state.\n\nIDPs in camps have restricted movement and other people are not allowed to enter them.\xa0\xa0A November survey stated that 68% of camps in Yobe, Adamawa, and Borno\xa0(149 camps) are without camp management.\n\nPeople arriving in Maiduguri, Borno state,\xa0go first to a camp where they are screened by the army, then move on either to Mouna camp,\xa0set up on\xa0private land, or to Custom camp, which consists of unfinished buildings hosting between 2,000 and 3,000 people.\xa0There are over 70,000 orphans living in Maiduguri and Monguno camps.\xa0\xa05% of all Borno IDPs are in camps; the remainder are in host communities.\xa0On 31 October, cases of rape and exploitation of IDPs in camps by government officials came to light, prompting\xa0President Buhari to launch an investigation, with no announcement of any results as of February 2017.\xa0\n\nReturns and relocations\n\nAs of 31 January, there were approximately 1,099,500 returnees in Adamawa, Borno and Yobe states.\xa0\xa0Large numbers of IDPs are returning for many reasons, including overcrowding and a lack of food, water, and basic services in IDP camps. Approximately 400,000 have returned\xa0to carry out farming.\xa0\xa0However, evidence also exists that IDPs are reluctant\xa0to return home.\xa0\n\nOn 21 February, the National Emergency Management Agency says about 310,000 IDPs have returned\xa0to seven LGAs that have been retaken in the past few months\xa0by the Nigerian army: 9,000 IDPs returned to Bama, 52,000 to Damboa, 67,000 from Dikwa, and 41,000 to Konduga.\xa0\xa0These areas have since come under increasing attacks on military and civilian positions. \xa0Military access leading to improved access is the primary driver of IDP\xa0returns.\xa0\n\nIn Adamawa, the National Emergency Management Agency reported that IDP numbers in Yola LGA dropped from 60,000 to about 19,000 by November.\xa0Over 3,000 refugees returned to Damasak town in Mobbar LGA, Borno, on 26 December.\u200b On 28 December, the Adamawa state government announced that it plans to\xa0close all of its IDP camps in January 2017; there are 21 camps in Adamawa that host approximately 11,757 people.\xa0\xa0\xa0\n\nIDP camp and community conditions\xa0\n\nBaga: There is an estimated population of 45,000 in Baga. Farming and fishing is heavily limited due to military operations. Its only health facility is damaged. Housing is inadequate and IDPs are squatting in destroyed structures and compounds. There are\xa0no education or sanitation facilities and prostitution\xa0in order to gain food or money to survive\xa0is taking place.\n\nBama:\xa0Once the second most populous Borno town, it is now virtually deserted and\xa0under army control. The entire population lives in the IDP camp ...

# %%
wpfeatures[0][0]
# Out:
# {'contains(mechanism.\xa0the)': False,
#  'contains(modira,)': False,
#  'contains(report)': True,
#  'contains(cadre)': False,
#  'contains(dineo,\xa0including)': False,
#  'contains(schoolgirls\xa0remain)': False,
#  'contains(buenaventura)': False,
#  'contains(337\xa0deaths)': False,
#  'contains(25,000\xa0in)': True,
#  'contains(camp.\xa0at)': False,
#  'contains(critically)': False,
#  'contains(by\xa0security)': False,
#  'contains(to\xa0one)': False,
#  'contains(strengthened)': True,
#  'contains(metals)': False,
#  'contains(yet.)': True,
#  'contains(acknowledge)': True,
#  'contains(euros)': False,
#  'contains(idps))': False,
#  'contains(tensions)': True,
#  'contains(curbs)': False,
#  'contains(area.a)': False,
#  'contains(tributaries,)': False,
#  'contains(wounded.the)': False,
#  'contains(refrain)': False,
#  'contains(territory.)': True,
#  'contains(public)': True,
#  'contains(darfur,\xa0have)': False,
#  'contains(issoufou)': False,
#  'contains(expenditure.)': False,
#  'contains(bathroom.)': False,
#  'contains(saw\xa0a)': True,
#  'contains(respective)': False,
#  'contains(assassinate)': False,
#  'contains(koutiala,)': False,
#  'contains(2015.\xa0so)': False,
#  'contains(2016\xa0because)': False,
#  'contains(amounts)': False,
#  'contains(el)': True,
#  'contains(deribat,)': False,
#  'contains(active,)': False,
#  'contains(shields)': False,
#  'contains(internal)': True,
#  'contains("non-denunciation)': False,
#  'contains(nationwide)': False,
#  'contains(the\xa0sudan)': False,
#  'contains(verified.\xa0over)': False,
#  'contains(reported.\xa0as)': False,
#  'contains(43%\xa0are)': False,
#  'contains(areas;\xa0most)': True,
#  'contains(area.\xa0\n\n\xa0\n\n\xa0\n)': False,
#  'contains(gaps.\xa0\xa0\n)': False,
#  'contains(retained)': False,
#  'contains(malnutrition\xa0are)': False,
#  'contains(use)': True,
#  'contains(situation.\n)': False,
#  'contains(from\xa04.1)': False,
#  'contains(saturated)': False,
#  'contains(october–november)': False,
#  'contains(3.5%.\xa0assessments)': False,
#  'contains((ptsd).)': False,
#  'contains((alleged)': False,
#  'contains(persist.\xa0oil)': False,
#  'contains(6,320)': False,
#  'contains(gna,)': False,
#  'contains(kusar)': False,
#  'contains(irrigation,)': False,
#  'contains(have\xa0ordered)': False,
#  'contains(countries.)': True,
#  'contains(13%.\xa0in)': False,
#  'contains(city\xa0stay)': False,
#  'contains(explosion)': False,
#  'contains(constrained,)': False,
#  'contains(treatment\xa0as)': False,
#  'contains(command.\xa0in)': False,
#  'contains(origin.\xa0the)': False,
#  'contains(war.\u200b)': True,
#  'contains(visit.)': False,
#  'contains(azar)': False,
#  'contains(“no)': False,
#  'contains(victim)': False,
#  'contains(mali)': False,
#  'contains(affiliates)': False,
#  'contains(mali\xa0since)': False,
#  'contains(disasters)': False,
#  'contains(equipment,)': False,
#  'contains(documented\xa0and)': True,
#  'contains(supplies.\xa0\n\nbaghdad\n\n2017)': False,
#  'contains(seasonal\xa0flash)': False,
#  'contains((minusca)\n\nminusca)': False,
#  'contains(souni)': False,
#  'contains(constraints.as)': False,
#  'contains(shortages.\n\nflooding)': False,
#  'contains(conflict.\xa0insulated)': False,
#  'contains(doing,)': False,
#  'contains(interviews)': False,
#  'contains(14/12/2015).\n)': False,
#  'contains(mutiny)': False,
#  'contains(farming,)': False,
#  'contains(worst)': False,
#  'contains(balochistan,)': False,
#  'contains(mudug.\xa0five)': False,
#  'contains(campaigns,)': False,
#  'contains(shores:)': True,
#  'contains(equatoria,\xa0leer)': False,
#  'contains(work.\xa0\n\nthe)': False,
#  'contains(raids)': False,
#  'contains(pre-existing)': False,
#  'contains(surveillance,)': False,
#  'contains(brokered)': True,
#  "contains(lna's)": False,
#  'contains(burto)': False,
#  "contains(russia's)": False,
#  'contains(90,000)': True,
#  'contains(promised\xa0the)': False,
#  'contains(dadaab,)': False,
#  'contains(districts.\n\nin)': False,
#  'contains(asylum)': True,
#  'contains(adequately,)': False,
#  'contains(78,500\xa0school-aged)': False,
#  'contains(old)': False,
#  'contains(buildings)': True,
#  'contains(kenya.\n\n\xa0\n)': False,
#  'contains(closed.\xa0shops)': False,
#  'contains(facilities\xa0it)': False,
#  'contains(governorates.\xa0on)': False,
#  'contains(\xa02016/17)': False,
#  'contains(influxes)': False,
#  'contains(900%\xa0in)': False,
#  'contains(fever\xa0cases)': False,
#  'contains(march.\xa0around)': False,
#  'contains(sent)': True,
#  'contains(are\xa0groups)': False,
#  'contains(peshmerga.)': False,
#  'contains(apply)': False,
#  'contains(resources)': True,
#  'contains(colombia\xa0since)': False,
#  'contains(appreciation)': False,
#  'contains(hospitals.\n)': False,
#  'contains(children.\xa0this)': False,
#  'contains(shortages.)': False,
#  'contains(takes)': False,
#  'contains(in\xa0ar)': False,
#  'contains(patrols)': False,
#  'contains(gedaref)': False,
#  'contains(\n\nindia–afghanistan)': False,
#  'contains(centres.\xa0the)': False,
#  'contains(of\xa0bdm)': False,
#  'contains(choice\xa0or)': False,
#  'contains(country.food)': False,
#  'contains(whipped,)': False,
#  'contains(belg)': False,
#  'contains(liberated)': False,
#  'contains(burimari,)': False,
#  'contains(hit)': True,
#  'contains(persecution.\n\nsunni)': False,
#  'contains(shortages.as)': False,
#  'contains(slower)': True,
#  'contains(pmu.\n\nthe)': False,
#  'contains(procedures.\n)': False,
#  'contains(mostly\xa0targeting)': False,
#  'contains(healthcare.\xa0according)': False,
#  'contains(country.\xa0\n\njubbaland\n\ndrought)': False,
#  'contains(first,)': False,
#  'contains(lualaba.\n\nthe)': False,
#  'contains(are\xa0jihadist)': False,
#  'contains(joint)': False,
#  'contains(people.the)': False,
#  'contains(be\xa0occupying)': False,
#  'contains(provinces.\xa0at)': False,
#  'contains(attacks.\xa0in)': False,
#  'contains(sagaing)': False,
#  'contains(nomadic)': False,
#  'contains(maraket,)': False,
#  'contains(of\xa029,000)': True,
#  'contains(in\xa0mid-january.)': False,
#  'contains(mogadishu,)': False,
#  'contains(169.)': False,
#  'contains(copper,)': False,
#  'contains(offending)': False,
#  'contains(divided\xa0in)': False,
#  'contains(poles\xa0had)': False,
#  'contains(alleges)': False,
#  'contains(average.\n\nsince)': False,
#  'contains(closures.\xa0monitoring)': False,
#  'contains(kambove,)': False,
#  'contains(one,)': False,
#  'contains(tanganyika.\n)': False,
#  'contains(violations.\xa0on)': False,
#  'contains(force,\xa0unisfa,)': False,
#  "contains((pakistan's)": False,
#  'contains(nangarhar)': False,
#  'contains(2016.\xa0\xa0sanctions)': False,
#  'contains(moves)': True,
#  'contains(devices.\xa0despite)': False,
#  'contains(water\xa0(unicef)': False,
#  'contains(indicates)': False,
#  'contains(of\xa0persistent)': False,
#  'contains(rainfal;\xa0this)': False,
#  'contains(displacement\xa0until)': True,
#  'contains(2017.\xa0\n\na)': False,
#  'contains(ballot)': False,
#  'contains(transitional)': False,
#  'contains(weekly,)': False,
#  'contains(india,)': False,
#  'contains(in\xa0namhsan\xa0in)': False,
#  'contains(ex-seleka,)': False,
#  'contains(42\xa0civilians)': False,
#  'contains(requesting)': False,
#  'contains(ukrainians)': False,
#  'contains(khanabad)': False,
#  'contains(signing)': True,
#  'contains(risk.\xa0at)': False,
#  'contains(3.1)': True,
#  'contains(manabí.)': False,
#  'contains(kinshasa)': False,
#  'contains(allowances\xa0from)': False,
#  'contains((pkk):\xa0considered)': False,
#  'contains(lebanese)': False,
#  'contains(pasture,)': False,
#  'contains(uganda.the)': False,
#  'contains(farmland\xa0in)': True,
#  'contains(rwanda,)': False,
#  'contains(5.1)': False,
#  'contains(moderately\xa0food)': False,
#  'contains((439,000))': False,
#  'contains(also\xa0been)': False,
#  'contains(million.\xa0\n\nmedia)': False,
#  'contains(fire,)': False,
#  'contains(\xa0\xa0\n\nan)': False,
#  'contains(otma)': False,
#  'contains(\xa0the)': False,
#  'contains(resolution)': False,
#  'contains(latrines)': False,
#  'contains(limpopo)': False,
#  'contains(size)': False,
#  'contains(motions)': False,
#  'contains(large,)': False,
#  'contains(children;)': False,
#  'contains(list.\xa0although)': False,
#  'contains(5,900)': False,
#  'contains((equateur))': False,
#  'contains(4.8)': False,
#  'contains(year.\xa0\n\nthe)': False,
#  'contains(spends)': False,
#  'contains(entry\xa0to)': False,
#  'contains(killings\xa0of)': False,
#  'contains(clear\xa0how)': False,
#  'contains(2012.\n\nsecurity)': False,
#  'contains(enawo,)': False,
#  'contains(general,)': True,
#  'contains(comprising)': False,
#  'contains(outcomes.from)': False,
#  'contains(bago,)': False,
#  'contains(repaired)': False,
#  'contains(3-4)': True,
#  'contains(38,940)': True,
#  'contains(2009.\xa0pakistan)': False,
#  'contains(un-led)': False,
#  'contains(251,000)': True,
#  'contains(harvests.the)': False,
#  'contains(shelters.\xa0many)': False,
#  'contains(affect\xa0school)': False,
#  'contains(group.\n\nthe)': False,
#  'contains(created\xa0after)': False,
#  'contains(to\xa043%)': False,
#  'contains(wei,)': False,
#  'contains(heavily.)': False,
#  'contains(inaccessible)': True,
#  'contains(marib,)': False,
#  'contains(2013),)': True,
#  'contains(isingiro,)': False,
#  'contains(at\xa02,200.\xa0\n)': False,
#  'contains(operating.\xa0\n\nall)': False,
#  'contains(require\xa0nfis.)': False,
#  'contains(under-five)': False,
#  'contains(amhara,)': False,
#  'contains(quarter,)': False,
#  'contains(one-party)': False,
#  'contains(patients.\n)': False,
#  'contains(435,000)': False,
#  'contains(stance)': False,
#  'contains(military\xa0and)': False,
#  'contains(bullring)': False,
#  'contains(medellin,)': False,
#  'contains(20s.)': True,
#  'contains(tutsis.\xa0according)': False,
#  'contains(average.\xa0similarly,)': False,
#  "contains(state's)": False,
#  'contains(those\xa0who)': False,
#  'contains(routes,)': False,
#  'contains(influx)': True,
#  'contains(lilongwe)': False,
#  'contains(do\xa01.8)': False,
#  'contains(anyone)': False,
#  'contains(impact\xa0on)': False,
#  'contains(impedes)': False,
#  'contains(lost)': False,
#  'contains(reported.schools)': False,
#  'contains(ajdabiya.)': False,
#  'contains(are\xa0in\xa0maroua)': False,
#  'contains(9,)': False,
#  'contains(18/02/2016).)': False,
#  'contains(ituri.\xa0\n)': False,
#  'contains(shippers,)': False,
#  'contains(aden)': False,
#  'contains((unrwa)': False,
#  'contains(closed.\n\n\xa0\n)': False,
#  'contains(sterilisation)': False,
#  'contains(estimates)': True,
#  'contains(ago,)': True,
#  'contains(eighth)': False,
#  'contains((eight)': False,
#  'contains(2,500)': True,
#  'contains(needs)': True,
#  'contains(government\xa0accused\xa0the)': False,
#  'contains(control\xa0where)': False,
#  'contains(crossing.\xa0)': False,
#  'contains(latest\xa0plan,)': False,
#  'contains((schouten)': False,
#  'contains(to\xa0an)': False,
#  'contains(muyinga)': False,
#  'contains(2,047)': True,
#  'contains(190,000).\xa0however,)': False,
#  'contains(228,000)': False,
#  'contains(ndindi)': False,
#  'contains(intentions)': False,
#  'contains(structure.\xa0in)': False,
#  'contains(31\xa0decemberer)': False,
#  'contains(mopti.\xa0\xa0numerous)': False,
#  'contains(slavery,)': False,
#  'contains(486,000,)': False,
#  'contains(supplementing)': False,
#  'contains(cooking,)': False,
#  'contains(line)': False,
#  'contains(245,272)': True,
#  'contains(litres)': False,
#  'contains(intercepting)': False,
#  'contains(largely)': True,
#  'contains(146,323)': False,
#  'contains(soap)': False,
#  'contains(321,000)': True,
#  'contains(296)': False,
#  'contains(widespread\xa0street)': False,
#  'contains(bombings.\xa0)': False,
#  'contains(patients.\xa0in)': False,
#  'contains(2013-2016.\n\nin)': False,
#  'contains(tsangano)': False,
#  'contains(agent)': False,
#  'contains(brigades)': False,
#  'contains(with\xa0low)': False,
#  'contains(logar.\xa0\n\nreturnees)': False,
#  'contains(1.63\xa0million)': True,
#  'contains(renamo,\xa0remains)': False,
#  'contains(and\xa0immediately)': False,
#  'contains((haut-uele))': False,
#  'contains(temporarily)': False,
#  'contains(gulistan-i-jauhar)': False,
#  'contains(calls)': False,
#  'contains(drought.\n\nbased)': False,
#  'contains(disarm)': False,
#  'contains(of\xa0spin)': False,
#  'contains(jonglei.fighting)': False,
#  'contains(unprotected)': False,
#  'contains(through\xa0djibouti)': False,
#  'contains(militias\xa0against)': False,
#  'contains(by\xa0water)': False,
#  'contains(below.)': True,
#  'contains(betwen\xa02008)': False,
#  'contains(doing)': True,
#  'contains(de-escalation)': True,
#  'contains(zataari)': False,
#  'contains(diseases,)': False,
#  'contains(kananga)': False,
#  'contains(39%\xa0to)': False,
#  'contains(260)': False,
#  'contains(arrested.)': False,
#  'contains(ranks.)': False,
#  'contains(chloride,)': False,
#  'contains(200km\xa0from)': False,
#  'contains(syria.\n\nas)': False,
#  'contains(attacks.\n)': False,
#  'contains(forces.\xa0the)': False,
#  'contains(separatists,\xa0but)': False,
#  'contains(low.\xa0\xa0el)': False,
#  'contains(regain)': True,
#  'contains(counties;)': False,
#  'contains(81%)': False,
#  'contains(blockades)': False,
#  'contains(indaza)': False,
#  'contains(landfall,)': True,
#  'contains(arrests,)': False,
#  'contains(village\xa0in)': False,
#  'contains(batafango,)': False,
#  'contains(obtain,)': False,
#  'contains(departments\xa0host)': True,
#  'contains(4).\xa0more)': False,
#  'contains(militarily)': False,
#  'contains(refuge\xa0in)': True,
#  'contains(three\xa0million)': True,
#  'contains(yuksekova,)': False,
#  'contains(saw\xa011,418)': False,
#  'contains(people))': False,
#  'contains(rest\xa0travel)': False,
#  'contains(marra,\xa0and)': False,
#  'contains(maize-producing)': False,
#  'contains(drought.\xa0the)': False,
#  'contains(humanitarians)': False,
#  'contains(southcentral)': False,
#  'contains(stronger\xa0than)': False,
#  'contains(the\xa0physical)': False,
#  'contains(contained)': False,
#  'contains(ban,)': False,
#  'contains(of\xa0obock)': False,
#  'contains(parties,)': False,
#  'contains(connection)': False,
#  'contains(2013.\n\nkenya\n\na)': False,
#  'contains(january.\xa0poor)': False,
#  'contains(\xa0water)': False,
#  'contains(have\xa0not)': True,
#  'contains(mouvements)': False,
#  'contains(583,175\xa0people)': True,
#  'contains(internally\xa0displaced\xa07.2\xa0million)': True,
#  'contains(armed\xa0attack)': False,
#  'contains(floated)': False,
#  'contains(mid-march.\n\nfood)': False,
#  'contains(one.\xa0the)': False,
#  'contains(unseasonal)': False,
#  'contains(rule)': False,
#  'contains(zimbabwe\xa0largely)': False,
#  'contains(march),)': False,
#  'contains(function,)': False,
#  'contains(restricted.)': False,
#  'contains(waiting)': True,
#  'contains(permits.\n\n263,600)': True,
#  'contains(239,000\xa0burundian)': False,
#  'contains(17\xa0march)': False,
#  'contains(march)': False,
#  'contains(republic\n\nas)': False,
#  'contains(afterwards,)': False,
#  'contains(the\xa0sudanese)': False,
#  "contains(mosul's\xa0old)": False,
#  'contains(kikuku)': False,
#  'contains(situation,)': True,
#  'contains(lenience)': False,
#  'contains(diamer)': False,
#  'contains(recorded.\xa0as)': False,
#  'contains(built)': True,
#  'contains(beat)': False,
#  'contains(clashes.\xa0\xa0\n\nabout)': False,
#  'contains(february.\n\noutlook\n\naccess)': False,
#  'contains((as)': False,
#  'contains(april.as)': False,
#  'contains(shutting)': False,
#  'contains(of\xa0oromo)': False,
#  'contains(areas\xa0most)': False,
#  'contains(women)': True,
#  'contains(sea,)': True,
#  'contains(expenditures)': False,
#  'contains(mid-february,)': False,
#  'contains(30.\xa0\n\n\xa0\n)': False,
#  'contains(land.\n)': False,
#  'contains(marsabit,\xa0samburu,\xa0tana)': False,
#  'contains(separatist-held)': False,
#  'contains(volumes)': False,
#  'contains(criticism)': False,
#  'contains(rehabilitate)': False,
#  'contains(camps,\xa0kirkuk)': False,
#  'contains(involving)': False,
#  'contains(disagreed)': False,
#  'contains(by-election.\xa0\n\nfemale)': False,
#  'contains(state.\xa0\xa0between)': False,
#  'contains(ituri)': False,
#  'contains(monthly\xa0caseload\xa0of)': False,
#  'contains(barzeh)': False,
#  'contains(\xa0\xa0on)': False,
#  'contains(a\xa0judge)': False,
#  'contains(four\xa0different)': False,
#  'contains(repair.\n\nthere)': False,
#  'contains(houses)': True,
#  'contains(bomber)': False,
#  'contains(earthquakes.\n)': False,
#  'contains((72,917),)': False,
#  'contains(shrine)': False,
#  'contains(in\xa0ghazni)': False,
#  'contains(warrant,)': False,
#  'contains(state\xa0who)': False,
#  'contains(2017\xa0in)': False,
#  'contains(repeatedly.)': False,
#  'contains(brother,)': False,
#  'contains(600km)': False,
#  'contains(bogotá-fusagasugá,)': False,
#  'contains(roughly)': True,
#  'contains(marara,)': False,
#  'contains(sabratha,)': False,
#  'contains(as\xa0discriminatory)': False,
#  'contains(governor.\n)': False,
#  'contains(chocó,\xa0antioquia,)': False,
#  'contains(outbreak,)': False,
#  'contains(hyperinflation)': False,
#  'contains(lebanon.\n\n\xa0\n)': False,
#  'contains(pastoralists.\n\nan)': False,
#  'contains(13.2%),)': False,
#  'contains(in\xa0ardo)': False,
#  'contains(for\xa0ransom)': True,
#  'contains(24-hour)': False,
#  'contains(repatriation\n\nfollowing)': False,
#  'contains(legalising)': False,
#  'contains(registered.\xa0malian)': False,
#  'contains(766,000)': False,
#  'contains(250)': True,
#  'contains(register)': True,
#  'contains(enable)': False,
#  'contains(were\xa0suspected)': False,
#  'contains(eastern\xa0equatoria,)': False,
#  'contains(construction)': True,
#  'contains(reported.\xa0\n)': False,
#  'contains(prophet)': False,
#  'contains(army)': True,
#  'contains(substantial)': False,
#  'contains(reservoir)': False,
#  'contains(toshkivka)': False,
#  'contains(sleet.\xa0\n\nat)': False,
#  'contains(distress.)': False,
#  'contains(caused\xa0damaged)': False,
#  'contains(disorders,)': False,
#  'contains(\xa07\xa0million)': False,
#  'contains(relocating.)': False,
#  'contains(pre-crisis)': False,
#  'contains(circles)': False,
#  'contains(at\xa065,000)': False,
#  'contains(rich)': False,
#  'contains(uncef-funded)': False,
#  'contains(houses\xa0according)': False,
#  'contains(reveals)': False,
#  'contains(54\xa0sites)': True,
#  'contains(agoudou-manga,)': False,
#  'contains(drainage)': False,
#  'contains(yemen\xa0is)': False,
#  'contains(weak.)': True,
#  'contains(nugaal)': False,
#  'contains(2.9)': True,
#  'contains(city\xa0has)': True,
#  'contains(seeing)': False,
#  'contains((is)\xa0has)': False,
#  'contains(seven\xa0months.)': False,
#  'contains(cameroon,)': False,
#  'contains(pierre)': False,
#  'contains(availability.\xa0on)': False,
#  'contains(child,)': False,
#  'contains(wei)': False,
#  'contains(on\xa0school)': False,
#  'contains(ould)': False,
#  'contains(–\xa0estimated)': True,
#  'contains(obtained)': False,
#  'contains(in\xa0cargo)': True,
#  'contains(52,500)': True,
#  'contains(of\xa0insecurity)': False,
#  'contains(strength)': False,
#  'contains(avengers,)': False,
#  'contains(jobar)': False,
#  'contains(aqap,)': False,
#  'contains(donbas)': False,
#  'contains(sudan\n\nthe)': False,
#  'contains(average.\xa0\n)': False,
#  'contains(bangui,)': False,
#  'contains(turkey,)': False,
#  'contains(seekers,\xa0after)': True,
#  'contains(gambia.in)': False,
#  'contains(blankets.main)': False,
#  'contains(11/05/2015).)': False,
#  'contains(were\xa0mainly)': True,
#  'contains(and\xa0president)': False,
#  'contains(\xa0\xa0many)': False,
#  'contains(desert)': False,
#  'contains(site.\xa0\xa0additionally,)': False,
#  'contains(shelters,)': True,
#  'contains(herdsmen,)': False,
#  'contains(drc.rwandan)': False,
#  'contains(2016\xa0in)': True,
#  'contains(crises,)': False,
#  'contains((fao)': False,
#  'contains(down)': True,
#  'contains(buyengo)': False,
#  'contains(qatar.)': False,
#  'contains(being)': True,
#  'contains(syria.\xa014,486)': False,
#  'contains(insecure.\xa0in)': False,
#  'contains(recognition.\n)': False,
#  'contains(cross-border)': True,
#  'contains(idp\xa0sites)': False,
#  'contains(491,550)': False,
#  'contains(intensity)': False,
#  'contains(2017.\xa0persistent)': False,
#  'contains(twice\xa0a)': False,
#  'contains(insufficiently)': False,
#  'contains(ethno-political)': False,
#  'contains(exceptional.\n)': False,
#  'contains(precipitation)': False,
#  'contains(putao)': False,
#  'contains(petrol)': False,
#  'contains(with\xa01,550,000)': False,
#  'contains(reported;)': True,
#  'contains(authorities\xa0due)': False,
#  'contains(women.\n)': False,
#  'contains(communities.\xa0\n\nacross)': False,
#  'contains(–\xa03,000)': False,
#  'contains(tanganyika)': False,
#  'contains(volume)': False,
#  'contains(sealed.)': False,
#  'contains(member\xa0living)': False,
#  'contains(between\xa05)': False,
#  'contains(terrorist)': True,
#  'contains(tanzania.\n)': False,
#  'contains(\xa0in\xa0locations)': False,
#  'contains(althought)': False,
#  'contains(mushasha,)': False,
#  'contains(nord-kivu\n\nin)': False,
#  'contains(11/01/2016).\n)': False,
#  'contains(improvement)': True,
#  'contains(are\xa0205,542)': True,
#  'contains(assistance.\xa0power)': False,
#  'contains(deny)': False,
#  'contains(member.)': False,
#  'contains(jere,)': False,
#  'contains(husband.)': False,
#  'contains(moyo,)': False,
#  'contains(depends.\n\ntensions)': False,
#  'contains(productivity,)': False,
#  'contains(benghazi)': False,
#  'contains(crackdowns)': False,
#  'contains(2,800\xa0from)': True,
#  'contains(in\xa0angola.\xa0as)': False,
#  'contains(commander\xa0summarily)': False,
#  'contains(third,)': False,
#  'contains(3,000\xa0from)': True,
#  'contains(intimidation\xa0and)': False,
#  'contains(\xa0awd)': False,
#  'contains(communities.\xa0the)': False,
#  'contains(entirely)': True,
#  'contains(heavily)': True,
#  'contains(marginal)': False,
#  'contains(bujumbara,)': False,
#  'contains(generations.)': False,
#  'contains(electricity,)': False,
#  'contains(catchment)': False,
#  "contains(movement'),)": False,
#  'contains(facilitator)': False,
#  'contains(unguided,)': False,
#  'contains(693)': False,
#  'contains(nganzai)': False,
#  'contains(who\xa0fled)': True,
#  'contains(economy)': True,
#  'contains(back\xa0in)': False,
#  'contains(january:)': False,
#  'contains(border.\xa0\n\njordan)': False,
#  'contains(work,)': False,
#  'contains(dramatically)': False,
#  'contains(\n\ncar:\xa04,930\xa0south)': False,
#  'contains(2016.\n\ncrossing)': False,
#  'contains(frequently.\xa0\n\ncholera\n\nas)': False,
#  'contains(dehydration)': True,
#  'contains(07/01/2016).)': False,
#  'contains(academics,)': False,
#  'contains(funding))': False,
#  'contains(seats)': False,
#  'contains(cfr\xa0of\xa011%,)': False,
#  'contains(in\xa0lower)': False,
#  'contains(skin)': False,
#  'contains(locality.clashes)': False,
#  'contains(seekers;\n\nvenezuela:\xa05,000)': False,
#  'contains(luba\xa0and)': False,
#  'contains(2017\xa0due)': False,
#  'contains(stadium)': False,
#  'contains(schools.in)': False,
#  'contains(surgical)': False,
#  'contains(avoid)': False,
#  'contains(11,156)': True,
#  'contains(ongoing\xa0since)': True,
#  'contains(needs.\n\nsyrian)': False,
#  'contains(foot-and-mouth)': False,
#  'contains((krg).\n)': False,
#  'contains(was\xa0authorised,)': False,
#  'contains(sidra)': False,
#  'contains(increased)': True,
#  'contains(430,000\xa0of)': True,
#  'contains(firewood,)': True,
#  'contains(process\xa0and)': False,
#  'contains(2.7%)': False,
#  'contains(workers\xa0per)': False,
#  'contains(turkey.\xa0in)': False,
#  'contains(angonia)': False,
#  'contains(liwa)': False,
#  'contains(coalitions)': False,
#  'contains(outbreaks\xa0affected\xa0wajir,)': False,
#  'contains(itself)': False,
#  'contains(executions,)': False,
#  'contains(available.\xa0oxygen)': False,
#  'contains(acknowledged)': True,
#  'contains(\xa0\xa0\n)': False,
#  'contains(january\xa0in)': False,
#  'contains(halfa)': False,
#  'contains(information))': False,
#  'contains(abadam,)': False,
#  'contains(urgent)': True,
#  'contains(home.\u200b)': False,
#  'contains(detainees)': False,
#  'contains(assessment),)': False,
#  'contains(4.3)': False,
#  'contains(groups.\xa0\xa0young)': False,
#  'contains(infestation.\xa0districts)': False,
#  'contains(base)': False,
#  'contains(sector.\n\nin)': False,
#  'contains(nord,)': False,
#  'contains(traffic)': False,
#  'contains(rukban.)': False,
#  'contains(harmonisé,\xa0of)': False,
#  'contains(regions.\xa0displaced)': False,
#  'contains(guajira.\n\nlimited)': False,
#  'contains(kitui,)': False,
#  'contains(alinjugur)': False,
#  'contains(high-risk)': True,
#  'contains(arid,)': False,
#  'contains(586,000)': False,
#  'contains(agency.\xa0a)': False,
#  'contains(kirsh)': False,
#  'contains(1,500)': True,
#  'contains(estimates,\xa08.08)': False,
#  'contains(a\xa0peak)': False,
#  'contains(del)': True,
#  'contains(restoring)': False,
#  'contains(january,\xa0hadi)': False,
#  'contains(primary)': True,
#  'contains(given\xa0the\xa0majority)': False,
#  'contains(troops,)': False,
#  'contains(2016,\xa0abu)': False,
#  'contains((government)': False,
#  'contains(to\xa0areas)': False,
#  'contains(borrowing)': False,
#  'contains(who\xa0oppose)': False,
#  'contains(to\xa0climate,)': False,
#  'contains(incomes.)': False,
#  'contains(inequality)': False,
#  'contains(marketing)': False,
#  'contains(polio-free)': False,
#  'contains(pequeños)': False,
#  'contains(difficult-to-access)': False,
#  'contains(country.\xa0the)': False,
#  'contains(million\xa0will)': False,
#  'contains(as\xa0mauritania)': False,
#  'contains(groups.\xa0about)': False,
#  'contains(internationally)': False,
#  'contains(expression)': False,
#  'contains(intelligence-based)': False,
#  'contains(civilians.\xa0aqap)': False,
#  'contains(gone)': True,
#  'contains(increase,)': False,
#  'contains(agreement)': True,
#  'contains(decrease\xa0compared)': False,
#  'contains(the\xa0price)': False,
#  'contains(waters.)': False,
#  'contains(verbally)': False,
#  'contains(prosecution)': False,
#  'contains(declared\xa0in)': False,
#  'contains(relied\xa0on)': False,
#  'contains(killed.\xa0concerns)': False,
#  'contains(mwene-ditu\u200b\xa0on)': False,
#  'contains(hygiene,)': False,
#  'contains(coffee)': False,
#  'contains(move)': True,
#  'contains(stolen)': True,
#  'contains(quality)': False,
#  'contains(march\xa0east)': False,
#  'contains(mortality)': False,
#  'contains(salamat,)': False,
#  'contains(struggles)': False,
#  'contains(65%.\xa0however,)': False,
#  'contains(to\xa0allegations)': False,
#  'contains(crucial)': False,
#  'contains(46%)': True,
#  'contains(17)': True,
#  'contains(few\xa0constraints)': False,
#  'contains(7,000–9,000)': True,
#  'contains(dozens)': False,
#  'contains(somaliland).\xa0in)': False,
#  'contains(palestinian)': False,
#  'contains(assistance.reports)': False,
#  'contains(taleba)': False,
#  'contains(grid.\xa0power)': False,
#  'contains(peaked)': False,
#  'contains(that\xa0refugees)': True,
#  'contains(pakistan.\xa0floods)': False,
#  'contains(hosts\xa024,550)': True,
#  'contains(bordering)': False,
#  'contains(yemen.\n\n\xa0\n)': False,
#  'contains(breast)': False,
#  'contains(protection.the)': False,
#  'contains(38,791)': True,
#  'contains(gilgit-baltistan)': False,
#  'contains((rural)': False,
#  'contains(inadequate.)': False,
#  'contains(may,)': False,
#  'contains(immunity)': False,
#  'contains(kordofan),)': False,
#  'contains(guilty,)': False,
#  'contains(roads.\xa0the)': False,
#  'contains(unimpeded)': False,
#  'contains(accessed)': False,
#  'contains(183)': False,
#  'contains(others.\xa0dikwa)': False,
#  'contains(fsa\xa0and)': False,
#  'contains(raids.)': False,
#  'contains(592,000)': False,
#  'contains(obama)': False,
#  'contains(increasingly\xa0reported)': False,
#  'contains(by\xa0october)': False,
#  'contains(settled)': True,
#  'contains(made.)': False,
#  'contains(mid-february.\n\ncholera)': False,
#  'contains(way)': True,
#  'contains(applies.)': False,
#  'contains(farming)': False,
#  'contains(card)': False,
#  'contains(earlier.)': False,
#  'contains(córdoba\xa0and)': False,
#  'contains(arab)': False,
#  'contains(these\xa0have)': False,
#  'contains(time)': True,
#  'contains(high.\xa0the)': False,
#  'contains(steadily)': False,
#  'contains(the\xa0emergency)': False,
#  'contains(xays/daada)': False,
#  'contains(hajjah,)': False,
#  'contains(payments)': False,
#  'contains(distances.)': False,
#  'contains(ruyigi.)': False,
#  'contains(off)': True,
#  'contains(provisional)': False,
#  'contains(connecting)': False,
#  'contains(containing)': False,
#  'contains(since\xa0late)': False,
#  'contains(mid-february)': False,
#  'contains(5th)': False,
#  'contains(2016,\xa0six)': False,
#  'contains(out.some)': False,
#  'contains(54,200)': True,
#  'contains(homes.\xa0soldiers)': False,
#  'contains(targeting,)': False,
#  'contains(infrastructure.\xa0\n\nrefugees)': False,
#  'contains(2016,\xa0more)': False,
#  'contains(destined)': False,
#  'contains(48,000)': False,
#  'contains(that\xa0the\xa0security)': True,
#  'contains(judge.\n\non)': False,
#  'contains(nyunzu,)': False,
#  'contains(tribune)': False,
#  'contains(hate)': False,
#  'contains(rates.\xa0\n)': False,
#  'contains(case-by-case)': False,
#  'contains(luapula)': False,
#  'contains(replanting.\xa0large)': False,
#  'contains(trading)': False,
#  'contains(registered)': True,
#  'contains(country.\xa02016)': False,
#  'contains(arms)': False,
#  'contains(31/10/2015).\xa0\n\ninsecurity)': False,
#  'contains(couple)': False,
#  'contains(fulani)': False,
#  'contains(building)': True,
#  'contains(camp,)': True,
#  'contains(height)': False,
#  'contains(rio)': False,
#  'contains(relocating\xa0to\xa0other\xa0neighbourhoods)': False,
#  'contains(bees,)': False,
#  'contains(actors.)': True,
#  'contains(clashes.\xa0\xa0)': False,
#  'contains(shells)': False,
#  'contains(05/2015).\n\npastoralists)': False,
#  'contains(teenagers,)': False,
#  'contains(facing\xa0catastrophe)': False,
#  'contains(in:\xa0kariba)': False,
#  'contains(fulani,\xa0is)': False,
#  'contains(2012.)': True,
#  'contains(appear\xa0to)': False,
#  'contains(defaulting)': False,
#  'contains(participating)': False,
#  'contains(productive)': False,
#  'contains(sulaiman)': False,
#  'contains(earlier)': False,
#  'contains(chain)': False,
#  'contains(rape,\xa0in)': False,
#  'contains((slm-aw);)': False,
#  'contains(2016\xa0with)': False,
#  'contains(id)': False,
#  "contains(into\xa0russia's)": False,
#  'contains(palmyra.)': False,
#  'contains(how\xa0migrants,)': False,
#  'contains(sidiki)': False,
#  'contains(for\xa0food,)': False,
#  'contains(result.on)': False,
#  'contains(rand,)': False,
#  'contains(\xa0according)': False,
#  'contains(among\xa0the)': False,
#  'contains(insecurity.\xa0\n\nas)': False,
#  'contains(cargo)': False,
#  'contains(90%\xa0of)': False,
#  'contains(less)': True,
#  'contains(road.\xa0in)': False,
#  'contains(ignited)': True,
#  'contains(46)': False,
#  'contains(a\xa0coup)': False,
#  'contains(gamboru)': False,
#  'contains(on\xa0the)': False,
#  'contains(water.\xa0in)': False,
#  'contains(food-producing)': False,
#  'contains(estimated\xa048,000)': False,
#  'contains(areas.\xa0food)': False,
#  'contains(arrival)': True,
#  'contains(kaga-bandoro)': False,
#  'contains(tribal)': True,
#  'contains(haram.\xa0\n)': False,
#  'contains(daily)': True,
#  'contains(other)': True,
#  'contains(opportunity)': True,
#  'contains(distributes)': False,
#  'contains(meaningful)': False,
#  'contains(1,097)': False,
#  'contains(greece,)': False,
#  'contains(deir-ez-zor.\xa0\n\nidlib:\xa0fighting)': False,
#  'contains(\xa0\xa0\n\none)': False,
#  'contains(uprooted)': False,
#  'contains(open,)': False,
#  'contains(reports)': True,
#  'contains(perceived\xa0by)': False,
#  'contains(160km)': False,
#  'contains(unity.two)': False,
#  'contains(living\xa0in)': True,
#  'contains(expensive\xa0private)': False,
#  'contains(unskilled)': False,
#  'contains(arrest,)': True,
#  'contains(10/03/2017\n\t\t\n\t\t\n\t\t\tiran\n\t\t\t32,149\n\t\t\tiom)': False,
#  'contains(be\xa0implemented,)': False,
#  'contains(opposition-held)': False,
#  'contains(rate\xa0in)': False,
#  'contains(been\xa0charging)': False,
#  'contains(stopped\xa0providing)': False,
#  'contains(sewage.\xa0on)': False,
#  'contains(380,000.\xa0according)': False,
#  'contains(march\xa0al)': False,
#  'contains(nam)': False,
#  'contains(renamo.)': False,
#  'contains(be\xa0high.)': False,
#  'contains(in\xa0processing)': False,
#  'contains(is\xa0increasing\xa0after\xa0the)': False,
#  'contains((brsc)\n\nansar)': False,
#  'contains(provisions)': False,
#  'contains(personnel.)': False,
#  'contains(deliberately\xa0targeted)': False,
#  'contains(liberals,)': False,
#  'contains(jos,)': False,
#  'contains(marra.\n\ncentral)': False,
#  'contains(2001.)': False,
#  'contains(erdogan\xa0could)': False,
#  'contains(in\xa0atsimo-andrefana)': False,
#  'contains(2016.\xa0on\xa013)': False,
#  'contains(rutshuru.since)': False,
#  'contains(lands,)': False,
#  'contains(moba)': False,
#  'contains(far\xa0on)': False,
#  'contains(flushing)': False,
#  'contains(sites,)': True,
#  'contains(removed)': False,
#  'contains(mid-march,)': False,
#  'contains(civilians;\xa0700)': False,
#  'contains(10,170)': True,
#  'contains(entire)': True,
#  'contains(accusations)': False,
#  'contains(security\xa0forces)': False,
#  'contains(inefficient)': False,
#  'contains(segou))': False,
#  "contains('rally')": False,
#  'contains(forces\xa0to)': False,
#  'contains(to\xa0both)': False,
#  'contains(2017.\xa0forces)': False,
#  'contains(yaounde.)': False,
#  'contains(sends)': False,
#  'contains(police.)': False,
#  'contains(chabahar,)': False,
#  'contains(insecurity.\n\nnorth)': False,
#  'contains(92,700)': False,
#  'contains(exponentially)': False,
#  'contains(disobey)': False,
#  'contains(amidst)': False,
#  'contains(political)': True,
#  'contains(people.\n\npoor)': False,
#  'contains(sanghan,)': False,
#  'contains(fact,)': False,
#  'contains(ingall)': False,
#  'contains(prolonged)': True,
#  'contains(11–12)': False,
#  ...}
