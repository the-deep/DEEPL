# %%
import nltk
import pandas as pd
import numpy as np
import scipy.stats
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-4e0671f4290a> in <module>()
#       2 import pandas as pd
#       3 import numpy as np
# ----> 4 import scipy.stats
#
# ~/Documents/work/code/venv/p3/lib/python3.6/site-packages/scipy/stats/__init__.py in <module>()
#     346 from __future__ import division, print_function, absolute_import
#     347
# --> 348 from .stats import *
#     349 from .distributions import *
#     350 from .morestats import *
#
# ~/Documents/work/code/venv/p3/lib/python3.6/site-packages/scipy/stats/stats.py in <module>()
#     173 from scipy._lib.six import callable, string_types
#     174 from scipy._lib._version import NumpyVersion
# --> 175 import scipy.special as special
#     176 import scipy.linalg as linalg
#     177 from . import distributions
#
# ...
